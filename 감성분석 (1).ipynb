# %%
import pandas as pd
from urllib.request import urlretrieve
import matplotlib.pyplot as plt
import re
import numpy as np
from sklearn.model_selection import train_test_split
from collections import Counter
import urllib.request
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Embedding, Dense, GRU
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.feature_extraction.text import CountVectorizer

# %%
# !pip install eunjeon
from eunjeon import Mecab
# Out:
# Collecting eunjeon
#   Downloading eunjeon-0.4.0.tar.gz (34.7 MB)
# Building wheels for collected packages: eunjeon
#   Building wheel for eunjeon (setup.py): started
#   Building wheel for eunjeon (setup.py): finished with status 'done'
#   Created wheel for eunjeon: filename=eunjeon-0.4.0-cp38-cp38-win_amd64.whl size=35014968 sha256=678d30fa3f6b7fceedeaf27597fe02c90e3ff8411e1e0d86ab34466f0da28121
#   Stored in directory: c:\users\ad\appdata\local\pip\cache\wheels\4b\1d\e9\bfa4c18245fc292aaa650fe6dd982a4feddfaab49f3b8f9f25
# Successfully built eunjeon
# Installing collected packages: eunjeon
# Successfully installed eunjeon-0.4.0

# %%
urllib.request.urlretrieve("https://raw.githubusercontent.com/bab2min/corpus/master/sentiment/naver_shopping.txt", filename="ratings_total.txt")
# Out:
# ('ratings_total.txt', <http.client.HTTPMessage at 0x1be4aa94070>)

# %%
total_data = pd.read_table('ratings_total.txt', names=['ratings', 'reviews'])
print('전체 리뷰 개수 :',len(total_data))
# Out:
# 전체 리뷰 개수 : 200000

# %%
total_data['label'] = np.select([total_data.ratings > 3], [1], default=0)
total_data[:5]
# Out:
#    ratings                                            reviews  label
# 0        5                                            배공빠르고 굿      1
# 1        2                      택배가 엉망이네용 저희집 밑에층에 말도없이 놔두고가고      0
# 2        5  아주좋아요 바지 정말 좋아서2개 더 구매했어요 이가격에 대박입니다. 바느질이 조금 ...      1
# 3        2  선물용으로 빨리 받아서 전달했어야 하는 상품이었는데 머그컵만 와서 당황했습니다. 전...      0
# 4        5                  민트색상 예뻐요. 옆 손잡이는 거는 용도로도 사용되네요 ㅎㅎ      1

# %%
total_data.drop_duplicates(subset=['reviews'], inplace=True)
print('총 샘플의 수 :',len(total_data))
# Out:
# 총 샘플의 수 : 199908

# %%
train_data, test_data = train_test_split(total_data, test_size = 0.25, random_state = 42)
print('훈련용 리뷰의 개수 :', len(train_data))
print('테스트용 리뷰의 개수 :', len(test_data))
# Out:
# 훈련용 리뷰의 개수 : 149931
# 테스트용 리뷰의 개수 : 49977

# %%
# 한글과 공백을 제외하고 모두 제거
train_data['reviews'] = train_data['reviews'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
train_data['reviews'].replace('', np.nan, inplace=True)
print(train_data.isnull().sum())
# Out:
# ratings    0
# reviews    0
# label      0
# dtype: int64
# <ipython-input-8-5c91c21161d5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['reviews'] = train_data['reviews'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
# C:\Users\ad\anaconda3\lib\site-packages\pandas\core\series.py:4563: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
test_data.drop_duplicates(subset = ['reviews'], inplace=True) # 중복 제거
test_data['reviews'] = test_data['reviews'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","") # 정규 표현식 수행
test_data['reviews'].replace('', np.nan, inplace=True) # 공백은 Null 값으로 변경
test_data = test_data.dropna(how='any') # Null 값 제거
print('전처리 후 테스트용 샘플의 개수 :',len(test_data))
# Out:
# 전처리 후 테스트용 샘플의 개수 : 49977
# <ipython-input-9-5968a3f5f2bc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data.drop_duplicates(subset = ['reviews'], inplace=True) # 중복 제거
# <ipython-input-9-5968a3f5f2bc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['reviews'] = test_data['reviews'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","") # 정규 표현식 수행

# %%
mecab = Mecab()
stopwords = ['도', '는', '다', '의', '가', '이', '은', '한', '에', '하', '고', '을', '를', '인', '듯', '것', '과', '와', '네', '들', '듯', '지', '임', '게']

# %%
train_data['tokenized'] = train_data['reviews'].apply(mecab.morphs)
train_data['tokenized'] = train_data['tokenized'].apply(lambda x: [item for item in x if item not in stopwords])
test_data['tokenized'] = test_data['reviews'].apply(mecab.morphs)
test_data['tokenized'] = test_data['tokenized'].apply(lambda x: [item for item in x if item not in stopwords])
# Out:
# <ipython-input-11-2ccd7617a3d9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['tokenized'] = train_data['reviews'].apply(mecab.morphs)
# <ipython-input-11-2ccd7617a3d9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['tokenized'] = train_data['tokenized'].apply(lambda x: [item for item in x if item not in stopwords])

# %%
negative_words = np.hstack(train_data[train_data.label == 0]['tokenized'].values)
positive_words = np.hstack(train_data[train_data.label == 1]['tokenized'].values)

# %%
negative_word_count = Counter(negative_words)
print(negative_word_count.most_common(20))
# Out:
# [('네요', 31823), ('는데', 20095), ('안', 19748), ('어요', 14869), ('있', 13200), ('너무', 13056), ('했', 11796), ('좋', 9797), ('배송', 9623), ('같', 8995), ('거', 8904), ('어', 8896), ('구매', 8884), ('없', 8695), ('아요', 8636), ('습니다', 8436), ('그냥', 8353), ('되', 8350), ('잘', 8029), ('않', 7986)]

# %%
positive_word_count = Counter(positive_words)
print(positive_word_count.most_common(20))
# Out:
# [('좋', 39365), ('아요', 21151), ('네요', 19906), ('어요', 18672), ('잘', 18612), ('구매', 16175), ('습니다', 13322), ('있', 12380), ('배송', 12263), ('는데', 11579), ('합니다', 9850), ('했', 9806), ('먹', 9453), ('재', 9252), ('너무', 8398), ('같', 7867), ('만족', 7225), ('거', 6485), ('기', 6341), ('어', 6317)]

# %%
X_train = train_data['tokenized'].values
y_train = train_data['label'].values
X_test= test_data['tokenized'].values
y_test = test_data['label'].values

# %%
#토큰화
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)

# %%
threshold = 2
total_cnt = len(tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value
        

print('단어 집합(vocabulary)의 크기 :',total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 39740
# 등장 빈도가 1번 이하인 희귀 단어의 수: 18056
# 단어 집합에서 희귀 단어의 비율: 45.4353296426774
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 0.7909317935219462

# %%
# 전체 단어 개수 중 빈도수 2이하인 단어 개수는 제거.
# 0번 패딩 토큰과 1번 OOV 토큰을 고려하여 +2
vocab_size = total_cnt - rare_cnt + 2
print('단어 집합의 크기 :',vocab_size)
print(X_train)
# Out:
# 단어 집합의 크기 : 21686
# [list(['사이즈', '센치', '씩', '늘린', '건데', '작', '아요', '그리고', '색상', '완전', '달라요', '칙칙', '핑크', '네요', 'ㅠㅠ', '많이', '아쉽', '지만', '암막', '효과', '좋', '아요'])
#  list(['ㅂ', '불', '만족', '빗이', '아픔', '멍', '피부', '빗', '질', '못해', '주', '겟', '네요'])
#  list(['제품', '쓰', '삼', '일', '만', '변기', '물', '잘', '안', '내려갔', '어요', '혹시나', '해서', '다시', '빼', '보', '니', '물', '다시', '잘', '내려가', '네요', '많', '걸', '어쩌', '나요', '반품', '싶'])
#  ... list(['장', '주문', '안', '됩니다', '장', '가능', '해요'])
#  list(['하림', '치킨', '여기', '서', '구입', '니', '엄청', '저렴', '네요', '배송', '쾅', '꽝', '얼', '어서', '도착', '아주', '만족', '합니다', 'ㅋㅋ'])
#  list(['조금', '약해', '보이', '는데', '저렴', '잘', '삿', '어요'])]

# %%
tokenizer = Tokenizer(vocab_size, oov_token = 'OOV') 
tokenizer.fit_on_texts(X_train)
X_train = tokenizer.texts_to_sequences(X_train)
X_test = tokenizer.texts_to_sequences(X_test)
print(X_train[:3])
print(X_test[:3])
# Out:
# [[66, 2066, 300, 14196, 260, 72, 6, 237, 169, 134, 806, 2938, 623, 2, 75, 61, 205, 39, 1355, 154, 3, 6], [478, 404, 52, 8472, 2596, 2372, 337, 2939, 247, 2386, 38, 471, 2], [43, 24, 816, 102, 34, 2373, 159, 7, 10, 8006, 4, 1325, 29, 138, 320, 44, 58, 159, 138, 7, 1934, 2, 112, 160, 1387, 301, 119, 133]]
# [[14, 710, 771, 117, 185, 248, 12], [337, 3901, 61, 3816, 1606], [11, 69, 2, 48, 164, 3, 15, 6, 512, 288, 17, 92, 109, 584, 58, 7, 2]]

# %%
print('리뷰의 최대 길이 :',max(len(l) for l in X_train))
print('리뷰의 평균 길이 :',sum(map(len, X_train))/len(X_train))
# Out:
# 리뷰의 최대 길이 : 85
# 리뷰의 평균 길이 : 15.226184044660544

# %%
def below_threshold_len(max_len, nested_list):
  cnt = 0
  for s in nested_list:
    if(len(s) <= max_len):
        cnt = cnt + 1
  print('전체 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(max_len, (cnt / len(nested_list))*100))

max_len = 80
below_threshold_len(max_len, X_train)
X_train = pad_sequences(X_train, maxlen = max_len)
X_test = pad_sequences(X_test, maxlen = max_len)
# Out:
# 전체 샘플 중 길이가 80 이하인 샘플의 비율: 99.99933302652553

# %%
model = Sequential()
model.add(Embedding(vocab_size, 100))
model.add(GRU(128))
model.add(Dense(1, activation='sigmoid'))
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=4)
mc = ModelCheckpoint('best_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
history = model.fit(X_train, y_train, epochs=15, callbacks=[es, mc], batch_size=60, validation_split=0.2)
# Out:
# Epoch 1/15
# 2000/2000 [==============================] - 102s 50ms/step - loss: 0.3240 - acc: 0.8685 - val_loss: 0.2460 - val_acc: 0.9140
#
# Epoch 00001: val_acc improved from -inf to 0.91396, saving model to best_model.h5
# Epoch 2/15
# 2000/2000 [==============================] - 98s 49ms/step - loss: 0.2173 - acc: 0.9210 - val_loss: 0.2136 - val_acc: 0.9237
#
# Epoch 00002: val_acc improved from 0.91396 to 0.92367, saving model to best_model.h5
# Epoch 3/15
# 2000/2000 [==============================] - 100s 50ms/step - loss: 0.2002 - acc: 0.9268 - val_loss: 0.2035 - val_acc: 0.9261
#
# Epoch 00003: val_acc improved from 0.92367 to 0.92610, saving model to best_model.h5
# Epoch 4/15
# 2000/2000 [==============================] - 101s 50ms/step - loss: 0.1868 - acc: 0.9340 - val_loss: 0.2080 - val_acc: 0.9254
#
# Epoch 00004: val_acc did not improve from 0.92610
# Epoch 5/15
# 2000/2000 [==============================] - 103s 51ms/step - loss: 0.1782 - acc: 0.9366 - val_loss: 0.2053 - val_acc: 0.9266
#
# Epoch 00005: val_acc improved from 0.92610 to 0.92663, saving model to best_model.h5
# Epoch 6/15
# 2000/2000 [==============================] - 100s 50ms/step - loss: 0.1695 - acc: 0.9403 - val_loss: 0.2051 - val_acc: 0.9265
#
# Epoch 00006: val_acc did not improve from 0.92663
# Epoch 7/15
# 2000/2000 [==============================] - 99s 49ms/step - loss: 0.1563 - acc: 0.9458 - val_loss: 0.2076 - val_acc: 0.9261
#
# Epoch 00007: val_acc did not improve from 0.92663
# Epoch 00007: early stopping

# %%
loaded_model = load_model('best_model.h5')
print("\n 테스트 정확도: %.4f" % (loaded_model.evaluate(X_test, y_test)[1]))
# Out:
# 1562/1562 [==============================] - 11s 7ms/step - loss: 0.2100 - acc: 0.9254
#
#  테스트 정확도: 0.9254

# %%
positive_data = []
negative_data = []

def sentiment_predict(new_sentence):
  print(new_sentence)
  sentence_noun = mecab.nouns(new_sentence)
    
  new_sentence = mecab.morphs(new_sentence) # 토큰화
  new_sentence = [word for word in new_sentence if not word in stopwords] # 불용어 제거
  encoded = tokenizer.texts_to_sequences([new_sentence]) # 정수 인코딩
  pad_new = pad_sequences(encoded, maxlen = max_len) # 패딩
  score = float(loaded_model.predict(pad_new)) # 예측
  if(score > 0.5):
    print("{:.2f}% 확률로 긍정 리뷰입니다.".format(score * 100))
    positive_data.append(sentence_noun)
  else:
    print("{:.2f}% 확률로 부정 리뷰입니다.".format((1 - score) * 100))
    negative_data.append(sentence_noun)

# %%
#이 아래는 예시 리뷰

# %%
df_data = pd.read_csv('바인드 백팩 블랙_최종_.csv', index_col = 0)

# %%
df_data
# Out:
#      별점                                               리뷰내용
# 0    10  역시 마크곤잘레스..❤️ 사랑해요ㅠㅠ백팩 너무 예뻐요ㅠㅠ 엔젤키링은 조금 유치하지 ...
# 1    10                   가방 크기도 적당하고 언제든 들고 다니기 편한것 같습니다!
# 2    10              수납공간도 넓고 학교책가방용으로 샀는데 디자인도 이뻐서 추천해요!!
# 3    10  학생가방으로 딱이에요 다른가방에 비해 긴편이긴한데 길어서 오히려 이쁜 것같다고 하네...
# 4    10                             무난무난하게 잘메고다닐거같아요 추천합니다
# ..   ..                                                ...
# 796  10  근데 예뻐요 키가 161인데 엉덩이까지 오구 등짝을 다 덮어요 귀엽고 수납 공간 많...
# 797  10                     진짜러 수납공간크고 예쁘고 너무 잘산거같다는생각듭ㅂ니다
# 798  10               좋아요\n커서 많이 들어가고 3개로 나누어져 있어서 편하고 예뻐요
# 799  10  다른 브랜드 가방이랑 고민하다가 할머니도 이게 더 예쁘다고 하셔서 바로 이거로 구매...
# 800  10  진짜 너무 예쁘고 무엇보다 튼튼한게 느껴지고 수납공간이 착착 있는건 아니지만 잘 나...
#
# [801 rows x 2 columns]

# %%
df_data['리뷰내용'] = df_data['리뷰내용'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
df_data['리뷰내용'].replace('', np.nan, inplace=True)
print(df_data['리뷰내용'])
# Out:
# 0      역시 마크곤잘레스 사랑해요ㅠㅠ백팩 너무 예뻐요ㅠㅠ 엔젤키링은 조금 유치하지 않을까 ...
# 1                        가방 크기도 적당하고 언제든 들고 다니기 편한것 같습니다
# 2                    수납공간도 넓고 학교책가방용으로 샀는데 디자인도 이뻐서 추천해요
# 3      학생가방으로 딱이에요 다른가방에 비해 긴편이긴한데 길어서 오히려 이쁜 것같다고 하네...
# 4                                 무난무난하게 잘메고다닐거같아요 추천합니다
#                              ...
# 796    근데 예뻐요 키가 인데 엉덩이까지 오구 등짝을 다 덮어요 귀엽고 수납 공간 많아서 ...
# 797                       진짜러 수납공간크고 예쁘고 너무 잘산거같다는생각듭ㅂ니다
# 798                    좋아요커서 많이 들어가고 개로 나누어져 있어서 편하고 예뻐요
# 799    다른 브랜드 가방이랑 고민하다가 할머니도 이게 더 예쁘다고 하셔서 바로 이거로 구매...
# 800    진짜 너무 예쁘고 무엇보다 튼튼한게 느껴지고 수납공간이 착착 있는건 아니지만 잘 나...
# Name: 리뷰내용, Length: 801, dtype: object

# %%
lists = np.array(df_data['리뷰내용'].tolist())
print(lists[1])
# Out:
# 가방 크기도 적당하고 언제든 들고 다니기 편한것 같습니다

# %%
for i in range (len(lists)):
    sentiment_predict(lists[i])
    print("")
# Out:
# 역시 마크곤잘레스 사랑해요ㅠㅠ백팩 너무 예뻐요ㅠㅠ 엔젤키링은 조금 유치하지 않을까 라는 생각이였는데 절때 아니예요 엔젤키링이 있어야 확 사는 느낌이더라구요 앞으로 쭉 이 백팩만 매고 다닐 예정입니당 가방 고민하고 계시면 무조건 마크곤잘레스 추천드립니다
# 91.77% 확률로 긍정 리뷰입니다.
#
# 가방 크기도 적당하고 언제든 들고 다니기 편한것 같습니다
# 50.92% 확률로 부정 리뷰입니다.
#
# 수납공간도 넓고 학교책가방용으로 샀는데 디자인도 이뻐서 추천해요
# 68.07% 확률로 긍정 리뷰입니다.
#
# 학생가방으로 딱이에요 다른가방에 비해 긴편이긴한데 길어서 오히려 이쁜 것같다고 하네요메고 다닐때도 불편한 건 없어서 괜찮아요천사일명 바나나인형도 포인트로 생각보다 너무 튀어보이진 않고 귀여워요
# 90.47% 확률로 긍정 리뷰입니다.
#
# 무난무난하게 잘메고다닐거같아요 추천합니다
# 55.73% 확률로 부정 리뷰입니다.
#
# 예쁘고 좋아요 마감도 짱짱하고 안에도 넉넉해요
# 69.57% 확률로 부정 리뷰입니다.
#
# 진짜 가성비 너무 좋고 디자인구성가격 전부다 너무 좋아요 실물이 특히 너무 좋습니다
# 93.40% 확률로 긍정 리뷰입니다.
#
# 실제로 받으니 더 만족입니다 수납 공간도 넉넉하고 다양한 스타일에 활용할 수 있어서 더 좋아요
# 59.76% 확률로 긍정 리뷰입니다.
#
# 수납공간도 넓고 예쁘구 친구들도 다 가방 예뻐서 좋겟다 라구 해요
# 69.25% 확률로 긍정 리뷰입니다.
#
# 생각보다 만족스러운 제품 적당한 수납공간과 가성비 어떻게 입든 다 잘어울리는 가방
# 89.39% 확률로 긍정 리뷰입니다.
#
# 디자인이 이쁘고 포인트도 있어서 좋아요 바나나는 너무 귀여워서 누가 가져갈까봐 가방에 넣고 다님니다
# 70.16% 확률로 긍정 리뷰입니다.
#
# 등이 딴딴하고 크기도 너무 크지않아서 좋은 것 같아요
# 76.95% 확률로 부정 리뷰입니다.
#
# 노트북이 인치라 들어갈까 걱정했는데 넉넉하게 들어가요
# 82.22% 확률로 부정 리뷰입니다.
#
# 그냥 캐쥬얼에 딱 매고 다니기 좋고 넣고싶은거 다 넣어도 또 들어가는 마법
# 98.79% 확률로 부정 리뷰입니다.
#
# 오래오래기다리다 받았죠ㅎ그래도넘넘예뻐서 유쾌상쾌중남아에요요고요고 기다리느라학년때가방을 거의두달간 매고다녔다는ㅋㅋ너무 멋지게잘어울리죠
# 95.63% 확률로 긍정 리뷰입니다.
#
# 거북이 등딱지 느낌이 조금 있지만 너무 좋아요 가방 수납공간도 많고 좋습니다
# 89.92% 확률로 긍정 리뷰입니다.
#
# 달기달려서 짜증났지만 넘 맘에듭니당 울딸이 넘좋아해요
# 95.52% 확률로 부정 리뷰입니다.
#
# 완전 마음에 들어요 등산가방 같은 스타일인데 처음엔 앞 주머니 수납공간이 없는게 단점인 것 같았는데 오히려 없어서 깔끔해보이고 넓고 깊어서 안정감있습니당
# 94.81% 확률로 부정 리뷰입니다.
#
# 완전 만족해요 노트북이 인치라 큰 가방 아닌 이상 따로 들고 다녔어야했는데 가방에 잘 들어가고 등이랑 닿는 부분도 딱딱한 판  덧대어져있고 위에 쿠션도 있어서 등도 안아프고 가방도 잘 안틀어져서 좋아요
# 71.46% 확률로 부정 리뷰입니다.
#
# 가방 수납공간도 많고 디자인도 예뻐요 교복에 매도 이쁘고 대가 가장 잘 어울릴 거 같아요 인형도 줘서 좋아요
# 85.77% 확률로 긍정 리뷰입니다.
#
# 키에 작을까봐걱정했는데 크기만족 가볍고 좋아요
# 85.71% 확률로 긍정 리뷰입니다.
#
# 좀 여성이 많이 맬거같은 디자인이라 걱정했는데 이뻐요 나쁘지않네요 ㅎ
# 79.28% 확률로 긍정 리뷰입니다.
#
# 가방 진짜 큰데 큰 만큼 좋아서 너무 잘 쓰고 있어요 인형에 최고 포인트입니다
# 98.24% 확률로 긍정 리뷰입니다.
#
# 튼튼하면서책을많이넣어도흐트러지지않고잘잡아줍니다
# 72.79% 확률로 부정 리뷰입니다.
#
# 일다 수납공간이 많아서 편리하고 디자인도 튀지않고 깔끔해서 어떤 옷을 입어도 어지간하면 잘어울려요
# 63.54% 확률로 긍정 리뷰입니다.
#
# 딱 봤을 때 제일 예뻐서 구매했는데 너무 만족스러워요 수납 공간도 많아서 좋고 특히 인형이 포인트ㅎㅎ 여러분 모두 마크 곤잘레스 하세요
# 88.86% 확률로 긍정 리뷰입니다.
#
# 수납 공간도 많이 크고 이뻐여 인형도 엄청 귀엽구요
# 76.94% 확률로 긍정 리뷰입니다.
#
# 가방 디자인도 예쁘고 또 크고 넓어서 쓰기도 좋고인형도 예뻐서 가방이 최고의 패션 아이템이네여 ㅎ
# 71.58% 확률로 긍정 리뷰입니다.
#
# 아기자기하고 이뻐요 근데 가방은 커서 만ㅎ이많이 넣을수 있어서 좋아여
# 96.41% 확률로 부정 리뷰입니다.
#
# 학생용으로도 여행용으로도 레저용으로도 모두 좋아요 적극 추천 합니다
# 96.52% 확률로 긍정 리뷰입니다.
#
# 남자가 쓰기엔 너무 귀엽게 생기지 않았나 생각했는데 생각보다 괜찮아요
# 94.48% 확률로 긍정 리뷰입니다.
#
# 너무 예뻐용 헤헤 다들 구매하세오 헤헤 완존 귀여웅
# 65.76% 확률로 긍정 리뷰입니다.
#
# 가방 크고 수납공간도 많습니다 인형 달려있어서 너무 맘에 들어요
# 69.24% 확률로 부정 리뷰입니다.
#
# 아무옷이나 잘어울리고 수납공간도 많은 편입니다무엇보다 저 엔젤이가 마음에 들어요
# 71.17% 확률로 긍정 리뷰입니다.
#
# 너무 너무 이쁘네요키 센티예요내일 매고 나갈려구요
# 58.75% 확률로 부정 리뷰입니다.
#
# 이쁘고 괜찮은데 지퍼에 달린 스트링 당겨서 열려하면 잘 안열려서 지퍼까지 넉넉히 잡아야 잘 열려요
# 57.37% 확률로 긍정 리뷰입니다.
#
# 엔젤키링이 너무 귀엽고 가방도 너무 예쁘네요  수납공간도 넉넉하고 최고입니다
# 93.67% 확률로 긍정 리뷰입니다.
#
# 사이즈도 크고 수납공간도 많아서 좋았어요 마크곤잘레스인형과 티머니카드도 귀엽네요
# 89.81% 확률로 긍정 리뷰입니다.
#
# 디자인은 너무 귀엽고 좋아요크기도 크고 하지만 수납공간이 칸이 있는데넓지는 않아요바나나인 줄 알았던 천사인형이없었다면 좀 허전했을거 같은데 노랑색 뽀인트가 있어서 좋은거 같아요
# 83.62% 확률로 긍정 리뷰입니다.
#
# 글씨체가 너무 예쁘고 바나나가 포인트네요 잘입을게요
# 79.71% 확률로 긍정 리뷰입니다.
#
# 이 바나나 인형이 엄청 귀엽고 앞에 똑딱이도 있어서 좋아요
# 51.67% 확률로 부정 리뷰입니다.
#
# 튼튼해보여서 좋고 배송도 빨리 왔던것갗습니다
# 73.39% 확률로 부정 리뷰입니다.
#
# 수납공간 낭낭합니다 예쁘고요 인형도 귀엽고 카드도 멋지네요
# 62.40% 확률로 긍정 리뷰입니다.
#
# 생각했던 것보다 쫌 컸지만 예뻐요 사는거 완전 강추 특히 바나나 키링이 맘에 들어요 여는거 불편
# 92.86% 확률로 긍정 리뷰입니다.
#
# 가방이 엄청 가볍고 수납할 공간도 많아서 좋구여 디자인도 좋구여 실용송도 좋아요
# 55.87% 확률로 긍정 리뷰입니다.
#
# 가방 크고 좋아요 가방 밑부분에 받침에 없어서 좀 아쉬운데 쿠션 처리가 돼있어서 괜찮을 것 같아요 수납 칸은 많은데 칸마다 메쉬망같은 오거나이저가 중간 칸에 큰 거 개밖에 없어요 자잘한 수납은 거의 없다고 보시면 돼요 전체적으론 만족합니다
# 71.61% 확률로 긍정 리뷰입니다.
#
# 큰 걸 원하긴 했지만 생각보다 더 넉넉하고 큰 게 와서 여행용으로도 딱 좋을 것 같아요 같이 온 귀여운 키링도 너무 마음에 들어요 사은품도 마음에 들고 전체적으로 깔끔함과 귀여움이 조화로워서 유행 안 탈 느낌 크면서도 가볍고 내구성도 괜찮아 보여서 앞으로다 기대되는 가방이네용
# 95.74% 확률로 긍정 리뷰입니다.
#
# 가방 예쁘고 공간도 적당히 넓어서 검은 옷이랑 잘 어울립니다
# 77.62% 확률로 긍정 리뷰입니다.
#
# 바리바리 보따리장수라 왕 큰 가방 그리고 로고도 컸음좋겠다 생각했는데 튼튼하고 엄청 깊고 큰 수납공간을 가지고 있군요 스티커도 노트북 꾸미는데 잘 쓰겠습니다 짱짱 로고가 빛을 반사하는 것도 이쁘네여
# 80.19% 확률로 긍정 리뷰입니다.
#
# 생각보다 길고 용량도 넉넉합니다 전 가방보다 용량 커서 마음에 드네요 디자인도 이쁘구요
# 87.21% 확률로 부정 리뷰입니다.
#
# 디자인이 확실히 실물이 더 예쁘고요 바나나인형 너무 귀여워요 잘 쓰겠습니다
# 66.23% 확률로 부정 리뷰입니다.
#
# 무엇보다 가격도 괜찮고 따뜻하고 가성비가 아주 좋네요
# 56.86% 확률로 부정 리뷰입니다.
#
# 큼지막한 가방 찾고 있었는데 수납공간 널널해서 정말 좋은거 같고 새학기에 교과서 받아오는 정도만 아니면 처짐은 많이 없을거같아여
# 94.90% 확률로 긍정 리뷰입니다.
#
# 수납공간 넉넉하고요 인형도 예쁘고 전체적으로 다 예뻐서 좋은거 같아요  역시 믿고 사는 마크 곤잘레스
# 70.19% 확률로 긍정 리뷰입니다.
#
# 어 먼저노랭이가 너무 귀여웠구요또넉넉하구가성비가 좋은 거 같아요이렇게 하면 되나라고 여자친구가 말했어용 헤헤
# 90.49% 확률로 긍정 리뷰입니다.
#
# 가방이 가볍고 디자인도 깔끔해서 평소에 편하게 메고 다니기 좋을 것 같아요 수납공간도 넓고 많아서 짱짱 좋고요 그리고 노란색 엔젤인형 실제로 보니까 더 귀여워요ㅎㅎ
# 69.97% 확률로 부정 리뷰입니다.
#
# 가방이 진짜 너무 귀엽고요 어디에 매칳ㅐ도 옷이랑 잘 어울려요 너무 예쁩니다
# 81.97% 확률로 긍정 리뷰입니다.
#
# 동생 입학선물로 구매했는데 공간도 많고 크기도 딱적당하고 가벼워요 저 바나나가 너무 귀여워서 훔치고 싶을만큼 너무 탐나네요
# 76.02% 확률로 부정 리뷰입니다.
#
# 가방 이쁘고 딱 좋아요 잘 삿습니다 수납공간도 괜춘해요
# 86.67% 확률로 긍정 리뷰입니다.
#
# 하 너무 귀엽잖아요 받은 즉시 기분 좋아졌습니다
# 99.07% 확률로 부정 리뷰입니다.
#
# 일단 수납이 부분으로 나눠져있구 커요 두번째칸에 메쉬 있는게 자잘한거 넣어놓기 좋아요 그리고 저 키링 인형 붙여놓으니까 너무 기여워요
# 51.73% 확률로 부정 리뷰입니다.
#
# 중학생되는 아들의 새가방으로 픽가볍고 수납도 넉넉해요 받아보니 더맘에드네요여행가방으로도 괜찮을꺼같아요
# 98.21% 확률로 부정 리뷰입니다.
#
# 합리적인 가격에 좋은 상품 구매하였습니다 감사합니다
# 91.31% 확률로 부정 리뷰입니다.
#
# 캐주얼하게 메고 다닐려고 샀는데 딱 좋습니다 공간도 넉넉하고 분할도 잘돼있고 가볍습니다
# 86.24% 확률로 부정 리뷰입니다.
#
# 등 다 가릴 만큼 크고 예쁘네요 에어팟 걸고 댕기기 좋음
# 64.69% 확률로 긍정 리뷰입니다.
#
# 예뻐요 상하로 긴 느낌이고 안에 포인트색 좋네요
# 78.29% 확률로 긍정 리뷰입니다.
#
# 생각했던것보다 좀 더 크고 수납공간도 의외로 많아서 너무 만족했어용 무게도 매우 가벼워서 너무 좋습니당 아주 만족스러워용 ㅎㅎㅎ 디자인은 말 할 것도 없이 너무 이쁘구용
# 88.80% 확률로 긍정 리뷰입니다.
#
# 수납공간도 넉넉하고 무겁게 넣어도 안정감 있게 잡아줘서 편해요 ㅎㅎ
# 59.00% 확률로 긍정 리뷰입니다.
#
# 커버낫 너무 많아서 디네뎃이랑 이거랑 고민하다 삿는대 후회없어요 너무조아
# 87.06% 확률로 부정 리뷰입니다.
#
# 제가 산 가방중에 제일좋은 가방같아요 공간도 엄청넓어서 활용도 좋아용
# 52.23% 확률로 부정 리뷰입니다.
#
# 오렌지색깔도 선명하고 예쁘고 수납공간도 많은데다 가방메기에도 너무 편안하네요 남자친구 선물로 최고입니다 너무 좋아했어요 ㅎㅎ
# 99.59% 확률로 부정 리뷰입니다.
#
# 키 에 크기는 등 다 가리고 수납 넉넉 큰 노트북도 들어감 밑바닥이 사선이라 바닥에 놓았을 때 잘 넘어짐 커버낫보단 안 흔함 ㅎㅎ
# 51.14% 확률로 부정 리뷰입니다.
#
# 제가 생각했던 무난하게 데일리룩에 잘 어울리는 그런 가방이었습니다
# 92.55% 확률로 부정 리뷰입니다.
#
# 기대했던거보다 훨씬 맘에 들어용
# 50.96% 확률로 긍정 리뷰입니다.
#
# 크기도 적당하고 무난하게 매고 다니기 좋아여지퍼가 조금 아쉬울 뿐
# 66.32% 확률로 부정 리뷰입니다.
#
# 고민하다 싸게 풀려서 사봤는데 생각보다 만족도가 좋아요
# 67.34% 확률로 긍정 리뷰입니다.
#
# 사이즈 증말 딱이에여 ㅜㅜ 커버낫 사려다가 진짜 넘 흔해서 마크곤잘레스 샀는데 후회 없습니다 사고나서 품절된 거 보구 진짜 기뻤음
# 97.23% 확률로 긍정 리뷰입니다.
#
# 수납 공간도 많고 안에 오렌지 색인것도 포인트가 되는 것 같네욥
# 72.93% 확률로 긍정 리뷰입니다.
#
# 데일리 가방으로 사용하며 어떤 상황에서도 자연스러운 스타일로보여집니다로고가 가방 앞 전체에 있어서 염려했는데오히려 검정 가방이 심심하지 않아서 더 만족스러워요키 입니다
# 86.91% 확률로 긍정 리뷰입니다.
#
# 등짝 다가리는 큰 가방 찾고있었는데 딱이네요 블랙인데 열어보면 주황인게 넘 반전이라 더 매력있는 가방인 것 같습니다
# 99.77% 확률로 부정 리뷰입니다.
#
# 백팩 크기도 크고 가격도 착하고 디자인도 맘에드네요후기가많이없어서 고민하시는분들있으실거같은데 믿고 사셔도될거같아요
# 77.87% 확률로 부정 리뷰입니다.
#
# 힙하고 예쁩니다 그리고 편해요 노트북같이 무거운것을 넣어도 무게감이 안느껴집니다 까만가방이라 대충 아무옷이나 입어도 잘 어울려요
# 53.76% 확률로 부정 리뷰입니다.
#
# 잘쓰겠습니다ㅎㅎ지퍼부분 마감만 더 좋았으면 금상첨화였는뎁ㅠ
# 85.55% 확률로 부정 리뷰입니다.
#
# 어깨끈에 있는 캐릭터를 보자마자 겟하지 않으면 안되겠더군요 항상 제 옆에 붙어있는 친구같아요너므 귀여워요
# 99.61% 확률로 부정 리뷰입니다.
#
# 다들 가방보고 귀엽대요 저랑 잘 어울릴 것 같아요 자기가 귀엽다 그럼 꼭 사세오 귀여움이 배가 된답니다
# 64.42% 확률로 부정 리뷰입니다.
#
# 사이즈도 딱 적당하고 이쁘네요노란색 인형이 포인트를줘서 더 이뻐용
# 72.69% 확률로 긍정 리뷰입니다.
#
# 진짜 이쁘고 제 마음에드는 최애 가방이 되었는데맥북 에어 별로 무섭지도 않은데 그거 넣고 들었다가어깨쪽이 찢어지네요학교다닐 때 부모님이 사주시던 가방들은 그렇게 무거운 책들 다 넣고 들어도 끄떡없었는데 이건 정말 아쉬워요 너무 예뻐서 매일들규 다니는데 수선해서 들고 다녀야 할 것 같아요
# 95.67% 확률로 부정 리뷰입니다.
#
# 인형포인트에 가방로고 잘어울리는것같아요 크기도 넉넉하구요
# 74.85% 확률로 긍정 리뷰입니다.
#
# 디자인 자체는 굉장히 예쁜데 가방 자체 크기가 조금 작아요
# 57.69% 확률로 긍정 리뷰입니다.
#
# 달려있는 인형이 귀여워요수납공간도 넉넉해서 맘에들어요
# 78.96% 확률로 부정 리뷰입니다.
#
# 가방도 튼튼하고 크기도 딱 적당해서 추천합니다물론 바나나가 귀여워요 ㅠ
# 89.47% 확률로 부정 리뷰입니다.
#
# 예쁘고 편리하고 좋아요배송도 빠르고완전 만족합니다
# 89.75% 확률로 부정 리뷰입니다.
#
# 마크곤잘래스 마크 인형 줘서 넘 좋아요 ㅠㅠ가방 진짜 예쁩니다공간도 넓어서 잘 쓰고 있어요
# 94.93% 확률로 긍정 리뷰입니다.
#
# 수납공간이 넉넉하긴 하지만 작은 포켓 같은게 몇개 더 있었으면 좋았을꺼 같아요 그래도 너무 이쁘고 배송도 빠르고 좋아요
# 64.82% 확률로 긍정 리뷰입니다.
#
# 완전 만족햐요 공간도 널널하고 생각보다 빨리와서 너무 좋았어용
# 86.29% 확률로 긍정 리뷰입니다.
#
# 디자인 예뻐요 근데 수납 공간은 넓은데 작은 물건들 담는 주머니는 하나밖에 없네요 후기 보니까 가방끈 약하다는 말이 많아서 조심히 써야겠어요
# 62.76% 확률로 긍정 리뷰입니다.
#
# 수납공간도 넓고 학교책가방용으로 샀는데 디자인도 이뻐서 추천해요
# 68.07% 확률로 긍정 리뷰입니다.
#
# 산지 얼마 안됬는데 가방끈이 좀 떨어졌어요 그게 아쉬워요 다른건 다 괜찮습니다
# 69.05% 확률로 부정 리뷰입니다.
#
# 역시 마크곤잘레스 개인적으로 마크곤잘레스 로고를 좋아해서 디자인은 너무 마음에 들어요사이드포켓이랑 지퍼부분 디테일도 굳하지만 생각보다 수납공간이 단순한게 좀 아쉬워요가운데랑 맨앞 수납공간에 작은물건들 넣을 공간이 있었으면 더 좋았을 것같아요
# 88.99% 확률로 긍정 리뷰입니다.
#
# 가방이 예쁘고 디자인도 깔끔하고 마크곤잘레스 인형도 귀여워서 만족합니다
# 74.48% 확률로 긍정 리뷰입니다.
#
# 수납 공간이 많다는 게 가장 큰 장점인 것 같아요 가방 기본 무게도 가벼워서 마음에 들어요
# 58.96% 확률로 부정 리뷰입니다.
#
# 무난무난하게 잘들고다닐거같아요 추천합니다
# 50.79% 확률로 긍정 리뷰입니다.
#
# 수납할곳이 많고 천사가 포인트 예뻐요우리 애들 명다 이제품으로 구입해 줬네요
# 96.09% 확률로 부정 리뷰입니다.
#
# 우선 노란 바나나 갈매기같은 인형이 너무 귀엽고 수납공간 매우 널널해서 만족스럽습니다
# 95.07% 확률로 긍정 리뷰입니다.
#
# 가방 크기 적당하고 디자인이 예뻐요달려있는 인형도 마음에 들어요지퍼가 좀 안되는것이 약간 단점입니다
# 80.70% 확률로 부정 리뷰입니다.
#
# 생각했던 것 이상으로 수납공간이 커서 좋구요마크곤잘레스 디자인이 너무 예뻐서 가방 디자인이 이쁩니다
# 85.96% 확률로 긍정 리뷰입니다.
#
# 수납공간도 넉넉하고 들고다니기 편한 사이즈 입니다
# 58.19% 확률로 긍정 리뷰입니다.
#
# 예쁘고 좋아요 특히 인형이 나무 귀여워요ㅜ역시 믿고사는 마크곤잘레스
# 77.99% 확률로 부정 리뷰입니다.
#
# 가방이 예쁘고 좋아요 마크 곤잘레스 짱짱맨 예쁨
# 65.78% 확률로 긍정 리뷰입니다.
#
# 진짜 디자인 심플하면서 엣지있고 수납 공간도 넓고 좋아요 너무 이쁜거 같습니다
# 96.05% 확률로 긍정 리뷰입니다.
#
# 마크 곤잘레스 백팩 너무 좋네요 인형도 사은품으로 주어서 정말 귀엽고 좋습니다 감사합니다
# 58.93% 확률로 긍정 리뷰입니다.
#
# 수납공간이 넓고 많아서 물건을 나눠 담기 편해요 ㅎㅎ 크기도 커서 기준 엉덩이 살짝 덮어요디자인도 마음에 들고 책을 많이 넣어도 많이 무겁지않아요 ㅎㅎ
# 66.36% 확률로 긍정 리뷰입니다.
#
# 가방도 크고 수납 공간도 많고 귀여운 인형도 줘서 젛아요
# 79.03% 확률로 긍정 리뷰입니다.
#
# 엄청 클줄 알았는데 에 딱 맞더라구요수납공간도 넉넉했고 편합니다키링도 너무 귀여움요
# 81.68% 확률로 부정 리뷰입니다.
#
# 약간 생각보다 무거운데 바나나비둘기 너무 귀엽고 수납 공간도 넉넉해서 좋아요
# 95.04% 확률로 긍정 리뷰입니다.
#
# 디자인도 너무 예쁘고 특히 키링이 너무 귀여워요 너무 만족해요 수납공간도 널널하고 길이 조절도 잘 되고 좋아요
# 65.94% 확률로 긍정 리뷰입니다.
#
# 배송도 빠르고 엔젤 너무 귀여워요 가방 크기도 적당하고 넘 맘에 듭니다ㅠㅠ
# 89.85% 확률로 부정 리뷰입니다.
#
# 노트북이 인치라 들어갈까 걱정했는데 넉넉하게 들어가요
# 82.22% 확률로 부정 리뷰입니다.
#
# 항상매고다니고있습니다 커버낫은 너무많아서 마크 곤잘레스 가방으로 구매했어용
# 64.49% 확률로 부정 리뷰입니다.
#
# 생각했던 그 모양 그 재질 그대로고 딱 어느때나 들기좋고 가볍게 친구들이랑 박일 여행갈때도 들기 딱 좋을 것 같아요
# 96.49% 확률로 긍정 리뷰입니다.
#
# 오래오래기다리다 받았죠ㅎ그래도넘넘예뻐서 유쾌상쾌
# 84.75% 확률로 부정 리뷰입니다.
#
# 가방이 큼직해서 수납이 정말 편해요 크기에 비해 가벼워서 부담스럽지 않아요 어깨 부분도 충분히 폭신해서 무겁게 넣어도 어깨 아프지 않아요
# 88.73% 확률로 부정 리뷰입니다.
#
# 너무너무 귀여워요새내기 느낌 뿜뿜하는 디자인이랄까
# 60.96% 확률로 부정 리뷰입니다.
#
# 너무 좋아요 수납공간도 많고 정말 가방 잘 산것 같아요
# 80.73% 확률로 긍정 리뷰입니다.
#
# 달기달려서 환불하려했는데 드드어왔습니다
# 53.51% 확률로 부정 리뷰입니다.
#
# 다른 매장에서 미리 직접 착용해보고 구매한거라 더 만족해요 ㅎㅎ 아주 예뻐요 바나나 인형 없었으면 아쉬울 뻔 했는데 완벽하게 만족합니다
# 97.94% 확률로 부정 리뷰입니다.
#
# 가방 깔쌈하고 좋아요 사실 가방에 달린 마스코트때문에 구매했는데 은근 실용성 넘쳐서 자주 들고 다닙니당
# 59.25% 확률로 부정 리뷰입니다.
#
# 모양이랑 디자인이 너무 이뻐요 배송도 생각보다 빨리와서 너무 좋습니다
# 81.24% 확률로 긍정 리뷰입니다.
#
# 일단 디자인은 다들 아시다시피 예쁘구요 인형이 너무 말랑말랑하고 좋습니다
# 51.08% 확률로 부정 리뷰입니다.
#
# 가방 너무 예뻐요 월 일 발송이라하셔서 꾹 참고 기다리고 있었는데 빨리 오니까 선물받는 느낌들어서 완전 좋아요
# 91.72% 확률로 부정 리뷰입니다.
#
# 마크곤잘레스 로고도 은색이라 빤짝거려서 좋고 수납공간 많아서 좋아요
# 93.01% 확률로 긍정 리뷰입니다.
#
# 디자인 좋고 키링도 이쁘고마음에들어요단점은 처음에 냄세가 좀 나요
# 81.67% 확률로 부정 리뷰입니다.
#
# 고등아들 가방으로 넉넉하고 가볍고 무엇보다 이쁘네요가성비 정말 갑이네요
# 71.93% 확률로 긍정 리뷰입니다.
#
# 디자인이 과하지 않고 예뻐요 가방 높이가 엄청 긴 편이라서 가끔 불편하긴 한데 그만큼 수납 많이 되어서 좋습니다 등판 쿠션이 빳빳해서 모양이 구겨지지 않아서 좋네요 고등학생 대학생 용으로 괜찮고 등산 갈 때도 좋겠어요 무엇보다 엔젤이 귀여워요
# 89.60% 확률로 긍정 리뷰입니다.
#
# 가방 진짜 너무너무 이뻐요 역시 마크곤자르레스입니다
# 74.16% 확률로 긍정 리뷰입니다.
#
# 새학기라서 샀는데 크기도 적당하고 딱 좋아요 많이 들어가긴 하는데 너무 수납공간이 많은것도 있는 것 같아요 그래도 키링도 귀엽고 맘에 들어요
# 93.04% 확률로 부정 리뷰입니다.
#
# 가방 너무 이쁘구요 바나나 너무 귀여워요 ㅜ 취저 제대로네용
# 96.56% 확률로 부정 리뷰입니다.
#
# 요즘 학교갈 때 노트북이랑 전공책 아이패드 이렇게 많이 들고가는데 가방 예뻐서 무거워도 용서가 돼요
# 53.25% 확률로 긍정 리뷰입니다.
#
# 사진과동일 가볍고 착용감좋아요 수납공간넉넉하구 키에 가방이 작아보일까 걱정했는데 딱 좋아요
# 94.17% 확률로 긍정 리뷰입니다.
#
# 교복입고 다닐 때 매고 다니기 편합니다 엄청 이뻐요
# 62.55% 확률로 부정 리뷰입니다.
#
# 수납공간도 많고 예쁘고 튼튼하고 좋은데 한 가지 단점이 있다면 앞쪽에 비해 등판쪽 쿠션이 커서 가방을 내려놓으면 한 쪽으로 자꾸 기울어요 ㅜㅠ
# 53.49% 확률로 긍정 리뷰입니다.
#
# 생각보다 가방이 크긴 했는데 수납공간 넉넉한거 좋아해서 맘에 들었어요 인형도 귀여웠고 아이패드 넣고 다니기 좋을까 고민했는데 한 열개는 들어갈듯 근데 또 무게는 가벼워서 좋았습니다 추천해요 유행하는 디자인인데 마곤은 의외로 안흔하더라구요
# 98.29% 확률로 긍정 리뷰입니다.
#
# 가방 수납 공간도 크고 너무 예쁘네요 특히 앞에 키링이 너무 귀여워요ㅋㅋ
# 73.19% 확률로 부정 리뷰입니다.
#
# 수납공간도 넉넉하고이쁘고 깜찍한 가방입니다
# 63.70% 확률로 긍정 리뷰입니다.
#
# 수납공간도 넉넉하니 되게 유용하게 쓰고 있습니다 만족해요
# 66.67% 확률로 긍정 리뷰입니다.
#
# 가방 엄청 크고 귀여워요 인형도 맘에 들어요 가방안에 밴드에 인치 노트북은 안 들어가더라구요 그것만 좀 아쉬워요
# 99.41% 확률로 부정 리뷰입니다.
#
# 크기도 적당하고 수납공간도 넉넉해서 좋습니다ㅏ 마크 곤잘레스 로고 인형 넘 귀여워요 ㅜ
# 67.02% 확률로 긍정 리뷰입니다.
#
# 일단 수납공간이 많아서 편리하고 디자인도 튀지않고 깔끔해서 어떤 옷을 입어도 어지간하면 잘어울려요
# 52.30% 확률로 긍정 리뷰입니다.
#
# 예쁘고 귀여워요 조금 크긴 하지만요 마음에 들어요
# 95.96% 확률로 부정 리뷰입니다.
#
# 인형도 예쁘고 가방도 편해서 자주 매고다닐것 같아요
# 55.39% 확률로 긍정 리뷰입니다.
#
# 사이즈도 맘에들고 핏도 좋아서 너무 마음에들어요
# 97.61% 확률로 부정 리뷰입니다.
#
# 수납 공간도 꽤 크고 인형 귀엽네요 잘 쓰겠습니다
# 66.49% 확률로 긍정 리뷰입니다.
#
# 이제 고등학교 올라가서 가방하나 장만했는데 진짜 너무 예뻐요꼭 사세요 근데 축 처지는 느낌이 아니라 빳빳한 느낌이에요
# 90.48% 확률로 긍정 리뷰입니다.
#
# 지퍼가 잘 안열리는구 빼곤 디자인 수납공간 다 만족해요
# 79.91% 확률로 긍정 리뷰입니다.
#
# 용량도 생각보다 넓고 꿀템인듯 너무 잘만드셨어요
# 80.32% 확률로 부정 리뷰입니다.
#
# 사이즈나 수납공간이 적당하고 좋아요블랙 색감도 선명하고 트레이드마크 가방에 귀엽게 달려서 퀄리티 좋습니다키가  남학생이 매고 다니기 굿
# 80.08% 확률로 긍정 리뷰입니다.
#
# 고아들 신학기선물로 구매했어요수납공간 넉넉하고 디자인 정말 이뻐요맘에 쏙들어해요 중학생아들도 탐을 냅니다
# 72.14% 확률로 부정 리뷰입니다.
#
# 너무 너무 이쁘네요사이즈 좋아 보여요내일 매고 나갈려구요
# 70.05% 확률로 부정 리뷰입니다.
#
# 진짜 실물이 너무 귀여워요 저 바나나 너무 귀여워서 우리집 강아지가 탐을내요 하지만 안줄꺼에요 제꺼에요
# 55.26% 확률로 긍정 리뷰입니다.
#
# 수납 공간도 넉넉하고 귀엽고 깜찍하고 다합니다 특히 노란색 인형 귀여움
# 54.37% 확률로 긍정 리뷰입니다.
#
# 고등학생용으로 구입 했는데 좋습니다 추천 합니다
# 91.73% 확률로 부정 리뷰입니다.
#
# 이쁜게 책가방으로 딱이에요 수납공간도 많고 인형도 너무 맘에 듭니당
# 67.70% 확률로 부정 리뷰입니다.
#
# 빨리 배송받아서 만족합니다 맨처음 로고 있는 곳 지퍼 여닫을때 조금거친 감이 있지만 사용하다보면 괜찮아지겠죠 수납공간도 많고서번째 사진에 보이는 것처럼마감 상태가 살짝 아쉽지만 ㅜ맘에 쏘옥 드는 백팩
# 84.75% 확률로 긍정 리뷰입니다.
#
# 수납공간도 넉넉하고 키링 포인트도 진짜 맘에들고 좋네요
# 71.55% 확률로 긍정 리뷰입니다.
#
# 크기는 커요 그래서 좋구요 수납공간은 넓지는 않아요
# 80.78% 확률로 긍정 리뷰입니다.
#
# 이쁘고 괜찮은데 지퍼에 달린 스트링 당겨서 열려하면 잘 안열려서 지퍼까지 넉넉히 잡아야 잘 열려요
# 57.37% 확률로 긍정 리뷰입니다.
#
# 가방 수납 공간도 많고 가방 자체가 좀 커용 인형 귀여웡ㅎㅇ
# 86.55% 확률로 긍정 리뷰입니다.
#
# 사이즈도 넉넉하고 무게도 가벼워서 아주 만족합니다
# 67.50% 확률로 긍정 리뷰입니다.
#
# 학교 다닐때 사용하면 좋을거 같아요수납공간이 많아서 좋아요
# 64.48% 확률로 긍정 리뷰입니다.
#
# 가방이 가볍고 사이즈 넉넉해서 만족합니다배송도 빠르네요
# 52.81% 확률로 긍정 리뷰입니다.
#
# 역시 마크 곤잘레스 사은품으로 온 인형도 너무 귀엽고 가방도 생각했던거보다 엄청 크지도 않아서 완죤 좋아요 사이즈 딱 좋아요 너무 작지도 않고 대빵 크지도 않은 아무튼 새학기 가방으로 딱 좋아요 학교나 갈 수 있을지 모르겠는데ㅠㅠ 다만 지퍼 열때 좀 불편하다는점 빼고는 굿이예요 그뤠잇해요
# 87.27% 확률로 긍정 리뷰입니다.
#
# 가방은 너무 이뻐요 기대했던것보다 훨 이쁨 근데 이 키링 빼다가부러졋어요 ㅠㅠ 조심하세요 ㅎ
# 81.73% 확률로 긍정 리뷰입니다.
#
# 생각보다 크기가 좀 크지만 가방 너무 예뻐요ㅎㅎ 자주 맬것같아용
# 64.52% 확률로 긍정 리뷰입니다.
#
# 가방이쁘네요 중딩 딸아이 맘에 든대요 수납도 넉넉하고 년동안 끄떡없겠어앋
# 77.08% 확률로 부정 리뷰입니다.
#
# 중학교 다닐때 매고 다닐 책가방으로 샀는데 이쁘고 잘 사용할 것 같아요
# 80.18% 확률로 부정 리뷰입니다.
#
# 이 바나나 인형이 엄청 귀엽고 앞에 똑딱이도 있어서 좋아요
# 51.67% 확률로 부정 리뷰입니다.
#
# 빠나나가 생각보다 커서 훨씬기엽고 가볍고 수납공간도 넉넉해요 아무옷이랑 입어도 잘 어울릴것같습니다
# 91.26% 확률로 긍정 리뷰입니다.
#
# 가방이 탄탄하고 디자인이 귀여워요 가방 윗 부분이 올라와있는것 빼고는 다 너무 좋아요
# 60.51% 확률로 부정 리뷰입니다.
#
# 가방이 엄청 가볍고 수납할 공간도 많아서 좋구여 디자인도 너무 예뻐요
# 77.16% 확률로 긍정 리뷰입니다.
#
# 가방크기 좋고 많이 들어갈 것 같아요 작은 메쉬망같은 자잘한 수납은 좀 부족해요 전체적으로 만족합니다
# 68.17% 확률로 긍정 리뷰입니다.
#
# 까탈스러운 우리 엄마의 심사를 아주 스무스하게 넘어간 이 가방 칭찬해
# 99.40% 확률로 부정 리뷰입니다.
#
# 지퍼 열고 닫기가 좀 힘들긴 한데 ㄷㅏ 무시하고 그냥 넘 이뻐서 만족합니당 ㅎㅎ
# 73.52% 확률로 부정 리뷰입니다.
#
# 가방 예쁘고 공간도 적당히 넓어서 검은 옷이랑 잘 어울립니다
# 77.62% 확률로 긍정 리뷰입니다.
#
# 로고도 크고 이쁘게 잘 들어가고 수납공간도 실용적 이라서 좋아요
# 58.75% 확률로 긍정 리뷰입니다.
#
# 대학생인ㄷㅔ 노트북이랑 전공책 왕창넣어다니기 좋아요
# 77.39% 확률로 부정 리뷰입니다.
#
# 마곤 가방 너무 예뻐요ㅠㅠ새학기 가방이 필요해서 알아보다가 샀는데넘 만족해용 그리고 가방에 달려있는 마곤 인형이 ㄹㅇ졸귀탱티머니 카드도 너무 귀여워요ㅠㅠ
# 81.31% 확률로 긍정 리뷰입니다.
#
# 가방이 진짜 크고 수납하기 너무 좋을꺼 같습니다
# 86.70% 확률로 긍정 리뷰입니다.
#
# 실제로 보니 더 이쁜 것 같아요 같이 있는 인형도 잘 어울립니다
# 58.05% 확률로 긍정 리뷰입니다.
#
# 생각보다 크고 인형 너무 귀여워요 봄에 딱 어울림ㅎㅎ
# 64.60% 확률로 긍정 리뷰입니다.
#
# 이거 진짜 예뻐요 저는 키가 작아서 거북이 등딱지 마냥 딱 붙어서 다닐 줄 알았는데 생각보다는 안 커서 조아요 그래도 크기는 큰데 엄청 큰 건 아니고아 그냥 사실 엔젤 키링 받으려고 샀는데 사은품으로 온 티머니한테 꽂혔어요 그냥 예쁘니까 사세요
# 96.65% 확률로 긍정 리뷰입니다.
#
# 수납공간도 넉넉하고 사은품들도 다 너무 귀엽고 그냥 다 만족스러워요
# 70.48% 확률로 긍정 리뷰입니다.
#
# 지퍼가 좀 불편한거 빼고는 디자인도 이쁘고 수납공간도 넓고 좋습니다
# 87.49% 확률로 긍정 리뷰입니다.
#
# 생각한것보다는 큰듯한데 중학교 가는 아들녀석이 서낵한 가방 디자인도 괜찮고 수납도 넉넉하고 좋아요
# 95.73% 확률로 긍정 리뷰입니다.
#
# 수납공간도 적당하고 무게도 적당해서 잘 쓸 것 같아요
# 73.30% 확률로 긍정 리뷰입니다.
#
# 가방도 커서 많이 들어가고 이쁘네요 노트북도 잘 수납 되네요
# 53.94% 확률로 긍정 리뷰입니다.
#
# 엄청 큰데 엄청 귀여워요 노트북이랑 책 여러 권 넣어도 넉넉해요
# 53.43% 확률로 부정 리뷰입니다.
#
# 예뻐요ㅠㅠ 바나나인형 키링 너무 귀여워요 가방 받침대가 안에 없어서 책 많이 넣으면 쳐질 것 같기도 한데 디자인이 넘 예쁘네요
# 69.26% 확률로 긍정 리뷰입니다.
#
# 이번에 고등학교 올라가서 엄마가 사줬는데 너무 예뻐요
# 67.67% 확률로 부정 리뷰입니다.
#
# 나이키 가방 쓰다가 찢어져서 새로 샀는데 너무너무너무 귀여워요 지퍼는 새 거라서 그런지 빡빡한데 튼튼하고 수납공간도 많고 좋아요 정말   사실 엔젤 키링 갖고 싶어서 샀어여  행보캐 글고 티머니 카드도 내 서타일임 바꾸려고여
# 89.81% 확률로 부정 리뷰입니다.
#
# 용량 넉넉하고 디자인도 이쁩니다 전 가방보다 커서 좋아요
# 69.90% 확률로 부정 리뷰입니다.
#
# 실물 너무 예쁘고 바나나인형이 킬포인트인듯 수납공간도 엄청많아요 잘 받았습니다
# 93.55% 확률로 긍정 리뷰입니다.
#
# 생각보다 커요 수납공간도 넉넉하고 특히 바나나인형이 귀엽네요 완전 포인트되구요
# 85.98% 확률로 긍정 리뷰입니다.
#
# 수납공간이 진짜 낭낭합니다 그리고 모양이 길쭉해요
# 94.15% 확률로 긍정 리뷰입니다.
#
# 인형이랑 스티커가 너무 귀여워요 수납공간도 넉넉하고 가방이 커서 좋아요
# 60.58% 확률로 부정 리뷰입니다.
#
# 생각했던거보다는 안큰거 같아요 수납은 넉넉해보입니다 인형 귀여워요ㅎㅎ
# 78.67% 확률로 긍정 리뷰입니다.
#
# 초등학교를 졸업하면서 학교 기본 가방이 있었는데 갔다가 버리고 샀어요 너무 좋아요 키링도 귀여워요
# 96.45% 확률로 부정 리뷰입니다.
#
# 생각보다 가법진 않은데 그렇다고 막 무겁지도랂아유
# 52.36% 확률로 긍정 리뷰입니다.
#
# 바나나 너무 귀엽고 사이즈 적당해요 잘 쓸것같아요
# 75.23% 확률로 부정 리뷰입니다.
#
# 아들램 신학기가방으로 사줬는데 사이즈도 좋고 수납할공간도많고 디자인도 이쁘네요아이도 만족해요
# 97.09% 확률로 긍정 리뷰입니다.
#
# 이뻐요 사이즈도 넉넉하고 맘에 들어요 잘 삿습니다
# 96.54% 확률로 부정 리뷰입니다.
#
# 디자인보고 사서 가방퀄리티는 기대 안했는데튼튼하고 퀄이 너무 좋아서 놀랐어요 가방도 크고넉넉해서 넘 맘에 들어요 앞이 메쉬망으로 된거랑 고민했는데 이거 사길 잘한듯 진짜 너무 예쁨ㅠㅠ
# 93.11% 확률로 긍정 리뷰입니다.
#
# 수납공간 넉넉하고 디자인 너무 예쁩니다 좋아요
# 77.85% 확률로 긍정 리뷰입니다.
#
# 수납공간 넉넉하고 인형이 진짜 귀여웠여요 전체적으로 엄청 예뻐요
# 80.89% 확률로 긍정 리뷰입니다.
#
# 대학교 입학용으로 샀는데 인치 노트북 외에도 수납공간 남아요
# 50.51% 확률로 긍정 리뷰입니다.
#
# 배송도빠르고 디자인 진짜 예쁘네요 기대했던거보다 더더 예뻐요 그리고 키링이 넘 귀여워요
# 84.61% 확률로 긍정 리뷰입니다.
#
# 가방 이쁘고 크고 좋은거같아요 특히 바나나 키링이 포인트
# 73.43% 확률로 긍정 리뷰입니다.
#
# 상품을 받았을때 너무 새상품냄새가나서 좀 머리가 아프네요 수납공간도 생각보다 적어요 그래도 디자인은 이쁘네요
# 85.89% 확률로 부정 리뷰입니다.
#
# 옆에 달려있는 엔젤ㅋㅣ링 너무 귀여워요 완전 대만족 귯귯수납도 넉넉하고 칸도 나눠져 있어서 활용하기 좋을거같아요
# 72.90% 확률로 긍정 리뷰입니다.
#
# 어 먼저노랭이가 너무 귀여웠구요또넉넉하구가성비가 좋은 거 같아요이렇게 하면 되나
# 50.37% 확률로 긍정 리뷰입니다.
#
# 가방 색감이 이쁘고 디자인도 깔끔해서 마음에 들어요 무게가 가볍고 수납공간이 넓고 많아서 편하게 들고다니기도 좋은 것 같아요
# 61.59% 확률로 긍정 리뷰입니다.
#
# 동생 입학선물로 구매했는데 공간도 많고 크기도 딱적당하고 가벼워요 저 바나나가 너무 귀여워서 훔치고 싶을만큼 너무 탐나네요
# 76.02% 확률로 부정 리뷰입니다.
#
# 후기들이랑 사진 보니까 가방이 디따 커보이고 가방에 뭘 넣었는지 ㅂㅐ불뚝이 아재 이길래 구매를 망설였다그런데 배송온 요 녀석 걱정했던 만큼 크기가 크지도 않고 수납 공간들도 여유 있게 잘 빠졌다 무엇보다 팔달린 바나나 인형이 참 매력적이다
# 53.97% 확률로 긍정 리뷰입니다.
#
# 솔직히 너무 예쁘네요 갈매기가 너무 귀여워요 수납공간도 엄청 깊고 많아서 잘 쓸 것 같아요
# 54.32% 확률로 긍정 리뷰입니다.
#
# 이틀만에 왔어요 크기도 적당히 크고 디자인이 너무 예뻐요ㅜㅜ 엔젤키링이 포인트여서 너무 귀여워요가격 때문에 조금 고민했지만 그래도 너무 예뻐서 하나도 후회 안 합니다다른 분들은 가방 안이 주황색이라고 하셨는데 저는 그냥 검은색이었어요
# 77.89% 확률로 부정 리뷰입니다.
#
# 마침 세일해서 샀는데 크기도 커서 학교다니면서 들고다녀도 될 거 같아요 색깔도 선명하고 수납공간도 적당하고 노란색 인형이 너무 귀여워요
# 98.10% 확률로 부정 리뷰입니다.
#
# 생각만큼 예뻐요자 이상 너무 길어요 좀 줄여요
# 98.18% 확률로 부정 리뷰입니다.
#
# 인터넷 사진과 실물이 똑같습니다 아주 맘에 듭니다
# 62.42% 확률로 부정 리뷰입니다.
#
# 가방 가볍고 예뻐요 귀여운 바나나 인형도 아주 맘에 들어요  공간도 꽤 넉넉해서 들고 다니기 편할 것같아요
# 97.69% 확률로 부정 리뷰입니다.
#
# 가방 완전 이뻐요 생각보다 크고 수납공간도 딱 적당해요 그리고 마곤 키링이랑 사은품도 잘 받았습니다
# 94.93% 확률로 긍정 리뷰입니다.
#
# 물건 넣는 공간이 단으로 분리되어있어서 나눠서 넉넉하게 많이 넣을 수 있어서 좋아요 그리고 인형도 달려있어서 너무너무 귀엽고 예뻐요ㅠㅠ 노트북 넣어다니기에도 충분할만큼 적당히 크고 어깨쿠션처리가 잘 되어있어서 메고다녀도 안아파요 강추합니다
# 70.42% 확률로 긍정 리뷰입니다.
#
# 로고 정말 맘에 들구요 인형 사은품 맘에 들어서 좋아요
# 97.71% 확률로 부정 리뷰입니다.
#
# 그냥 예뻐요ㅎㅎ 저만 매고다니고싶네요 수납도 좋고요 귀여워요 맘에듭니다
# 98.39% 확률로 부정 리뷰입니다.
#
# 엄청 크고 낙낙해서 예뻐요 그리고 다른 가방에 비해서 안 흔해서 좋아요
# 65.14% 확률로 부정 리뷰입니다.
#
# 사진으로 봤던 것보다 실물이 훨씬 나아서 정말 마음에 듭니다 수납공간도 적당히 넓고 가방의 각이 잘 잡혀 있어서 좋네요 무엇보다 마크 곤잘레스 인형 진짜 너무 귀여워요ㅠㅠ
# 73.89% 확률로 긍정 리뷰입니다.
#
# 동일 브랜드 다른 디자인이랑 고민하다가 이 디자인이 뭔가 더 커보이고 많이 들어갈 것 같아서 구매했는데 만족합니다 ㅎ
# 63.61% 확률로 긍정 리뷰입니다.
#
# 가볍고 수납공간 많아서 좋아요 버스카드도 줘서 좋아요
# 85.86% 확률로 긍정 리뷰입니다.
#
# 너무 크면 어쩌나 걱정했는데 제가 딱 원하던 등을 다 덮어주는 정도이고 키링이 너무 귀엽고 예뻐요
# 98.61% 확률로 부정 리뷰입니다.
#
# 수납공간 엄청 널널하고 같이 달려오는 마크곤잘레스 노랭이 인형 너무 귀여워요ㅎㅎ 크기도 딱 적당하게 등 가려주고 남동생 선물로 줬는데 예쁘다면서 엄청청 마음에 들어했습니당
# 51.60% 확률로 긍정 리뷰입니다.
#
# 정말 이쁘고 공간이 엄청 넓어서 놀랐어요믿고쓰 입니다
# 78.50% 확률로 긍정 리뷰입니다.
#
# 굉장히 이뻐요 진짜 만족 진짜 흔하지도 않고 이뻐요꼭 사세용근데 좀 세로로 길이가 길어여
# 88.73% 확률로 긍정 리뷰입니다.
#
# 작을까봐 걱정했는데 생각보다 크고 수납할 곳도 많아서 좋았고 가방 너무 예뻐요
# 95.49% 확률로 긍정 리뷰입니다.
#
# 안에 공간 많아서 진짜 넣고 싶은거 다들어가요 이뻐용
# 83.91% 확률로 긍정 리뷰입니다.
#
# 보자마자 예뻐서 샀는데 키가 작다 보니 가방이 엄청 크더라고요 ㅜㅜ 가방 길이도 길어서 가방끈 짧게 사용하고있습니다 그래도 예뻐요
# 87.42% 확률로 긍정 리뷰입니다.
#
# 가방이 이쁘고 공간도 넉넉하고 편하게 사용하고있습니다
# 55.30% 확률로 긍정 리뷰입니다.
#
# 합리적인 가격에 좋은 상품 구매하였습니다 감사합니다
# 91.31% 확률로 부정 리뷰입니다.
#
# 다른건 다 좋은데 내구성이 좀고이라 책을 많이 갖고 다니는데 산지 이틀만에 가방끈과 가방을 잇는 부분이 일부 뜯어졌어요가방 사이즈를 크게 만들었으면 가방에 물건을 많이 담고 다닐 것을 감안해서 튼튼하게 만들었어야지 않나요
# 59.54% 확률로 긍정 리뷰입니다.
#
# 보기에도 이쁘고 실제로 써보니 수납공간도 무난하네요 커버낫은 너무 많아서 이 가방이 더 이뻐보이는듯
# 69.20% 확률로 부정 리뷰입니다.
#
# 진작부터 눈여겨보던 가방이었는데 할인해서 너무 저렴한 가격에 잘 샀습니다감사합니다
# 83.32% 확률로 부정 리뷰입니다.
#
# 작은 수납공간이 없어서 아쉽지만 디자인이 예뻐서 무조건만족하는 상품이에요 마크곤잘레스 로고가 진짜 예쁘게 반사되서 더 좋은것 같아요  많이 파세용
# 92.62% 확률로 긍정 리뷰입니다.
#
# 등 감출만큼 엄청 큽니다 디자인은 엄청 예뻐요 다만 지퍼나 안쪽 부직포 마감처리 별롭니다
# 95.06% 확률로 부정 리뷰입니다.
#
# 상하로 긴 느낌이고 안에 포인트색이 주황색이라서 괜찮네요
# 89.38% 확률로 긍정 리뷰입니다.
#
# 백팩 무지 튼튼하고 예뻐요  깔끔하구 맘에 듭니다
# 95.48% 확률로 부정 리뷰입니다.
#
# 가격도 적당하고 품질도 나쁘지않아요단점있다면 땅에 혼자서 잘 못서있는거
# 70.92% 확률로 부정 리뷰입니다.
#
# 실착예쁘고 구성좋아요 추천합니다 귀엽고그래요옹
# 95.28% 확률로 부정 리뷰입니다.
#
# 할인해서 샀는데 나쁘지 않네요 크기도 적당하고 편해요
# 70.88% 확률로 부정 리뷰입니다.
#
# 구매 후 수령까지 일주일이나 걸렸지만가방은 이쁘고 마음에 들어요생각했던 것 보다는 상하로 조금 긴 느낌이에요
# 88.80% 확률로 긍정 리뷰입니다.
#
# 이뻐요 안감이 너무 강렬한색이라당황햇지만 그래도 이뻐서 맘에듭니당 크기도 커유
# 94.52% 확률로 부정 리뷰입니다.
#
# 크기도 넉넉하고 예쁘네요 자주 매고 다닐거같아요
# 52.86% 확률로 부정 리뷰입니다.
#
# 클까봐 걱정했는데 생각보다 크지 않고 딱 이쁜 사이즈였어용  디자인도 이쁘고  맘에 드는데 하나 아쉬운점이 작은 수납 공간이 없다는거 그 점을 유의하고 샀는데도 조오금 아쉬웠으니까 사실분들은 참고하세요
# 85.75% 확률로 긍정 리뷰입니다.
#
# 크기가 꽤 크긴한데 괜찮아요 다만 세우면 계속 쓰러지고 가방 안의 보폭 이 좁아서 책 몇권 넣으면 필통 들어갈 자리가 없어요
# 63.93% 확률로 긍정 리뷰입니다.
#
# 수납공간은 해외여행이나 배낭여행 갈 때 사용하기엔 적고 학교가방으로 사용하기에 딱 알맞을 것 같고생각보다 넉넉 디자인도 깔끔한데다 내부 색깔도 이뻐서 정말 만족스럽습니다
# 53.12% 확률로 부정 리뷰입니다.
#
# 크기도 커서 수납용량도 크구요 안에 주황색 안감이 포인트에요 너무 예뻐요
# 74.98% 확률로 부정 리뷰입니다.
#
#  인치 노트북 여유있게 들어가고 수납공간도 많아서 좋아요
# 95.69% 확률로 긍정 리뷰입니다.
#
# 디자인이 너무이뻐요 한달을 기다려서 샀었는데 이제야 사용하네요 얼른 학교개학해서 매고다니고싶어여
# 82.88% 확률로 긍정 리뷰입니다.
#
# 디자인도 이쁘고 넉넉하고 정말 만족스럽습니다ㅎㅎ
# 55.18% 확률로 긍정 리뷰입니다.
#
# 브랜드값타서 비싼가방이긴한데 흔한가방보단 낫구 스타일도 괜찮은 가방인거같습니다 ㅎ
# 54.92% 확률로 긍정 리뷰입니다.
#
# 생각한것보다 훨씬 더 예쁘네용ㅠ큰 수납공간 많은거 제게 딱이예욤
# 92.63% 확률로 긍정 리뷰입니다.
#
# 마크곤잘레스 좋아하는 사람이면 좋아할거같아요 안에 노트북 넣을수있는 공간은 노트북 파우치 넣으면 안들어가고 생각보다 가방이 안이 큰게 아니라 위로만 큰 느낌 그냥 전공책 개랑 아이패드 들어가서 만족하고 쓰려구여
# 98.20% 확률로 긍정 리뷰입니다.
#
# 너무 예뻐여 ㅠㅠㅠㅠㅠ 적립금 모아둔거 써서 되게 싸게 샀는데 후회안해여 자잘한 수납공간은 없지만 그래도 좋아요 그냥 줗아요 크기도 적당한거같으면서 커보이는 느낌  딱 원하던 크기에 모양이에여 지퍼가 빡빡하다는 후기가 많아서 좀 걱정이였는데 막 불편한 정도는 아니에여 전 이 정도는 새가방사면 감당을 해야한다고 생각함다 고민하지말고 구매더보기
# 92.33% 확률로 긍정 리뷰입니다.
#
# 진짜 너무 이쁘고 수납공간 많아서 좋아요 그리고 안이 주황색이라 너무 이쁜듯요
# 83.64% 확률로 긍정 리뷰입니다.
#
# 가방 진짜 너무너무 좋은데 자잘한 수납공간이 없어서 아쉽긴해요 근데 진짜 본새 대박임 체고 마크곤잘레스 사랑해요 저 사실 맠곤 덕후임 ㅋ
# 89.66% 확률로 긍정 리뷰입니다.
#
# 디자인도 예쁘지만넒어서 물건이 잘들어가는게제일 좋아요
# 59.04% 확률로 부정 리뷰입니다.
#
# 완전 이뻐요자잘한 수납공간이 없어서 아쉽긴 하지만 이뻐서 괜찮아유지퍼 많이 불편하다고들 하는데 저는 별로 불편하지않앗어용 등 쿠션 받쳐주는거있어서 멜때 가볍게 멜수있고 좋습니다
# 60.41% 확률로 긍정 리뷰입니다.
#
# 좋아요 가격 싸게 사서 그렇지 원가로 구매하시는거면 추천 안드려요
# 93.06% 확률로 긍정 리뷰입니다.
#
# 고등학교 올라가는데 가방 뭐 살지 엄청 고민하다가 마크 건잘레스 이 가방이 너무 이뻐 보여서 이걸로 샀는데 너무 잘산거 같아요 안에 주황색이 진짜 너무 좋은거 같아요 학교에 잘 들고 다닐거 같아요 좋아요
# 60.59% 확률로 긍정 리뷰입니다.
#
# 진짜 맘에드네요 디자인부터 안에 수납공간도 넉넉하고
# 82.21% 확률로 긍정 리뷰입니다.
#
# 가방이 은근 커서 수납공간이 넓어요 로고 적혀있는게 포인트로 예쁩니다
# 87.99% 확률로 긍정 리뷰입니다.
#
# 가방의 디자인도 너무 예쁘고 많이 클까봐걱정했는데 가방을 메보니까생각보다 많이 크지않고 적당해요그치만 가방 지퍼가 많이 뻣뻣하고 걸리네요 ㅠ ㅠ이부분이 많이 아쉽지만 좋아요
# 66.99% 확률로 긍정 리뷰입니다.
#
# 텍 안떼고 매고 다니고싶을정도로 귀엽다
# 85.83% 확률로 부정 리뷰입니다.
#
# 가방은 크고 수납공간 많아서 좋습니다다만 크기가 너무 크고 무거워요ㅠㅠ
# 51.73% 확률로 긍정 리뷰입니다.
#
# 생각했던거 보단 사이즈가 쪼금 크긴한데 대학교가서 쓰려고 산거고 노트북도 넣고 다니려고 산거라 너무 만족해요ㅎ
# 95.70% 확률로 긍정 리뷰입니다.
#
# 일반가방보다 더 힙하게 스타일을 구성할 수 있고 편하고 가방도 넓어요 개성있이 옷 입는분들에게 강추합니다 일반인도 마찬가지
# 80.53% 확률로 부정 리뷰입니다.
#
# 백팩 사고시퍼서 샀는데 크네욤 근데 큰거 좋아해서 ㄱㅊㄱㅊ 잘 메고다닐게요
# 69.34% 확률로 부정 리뷰입니다.
#
# 이쁘네요 크기가 생각보다 좀 크긴한데 많이 작은 여성분한테는 너무 커서 이상해보일수도 있어요 보통 체형이시면 무난할듯
# 61.86% 확률로 긍정 리뷰입니다.
#
# 너무 비싼 백팩은 부담스러워서 이거 샀는데 가격 대비 엄청 좋네요 오래오래 쓸수 있을거 같아요
# 77.36% 확률로 부정 리뷰입니다.
#
# 월초에 사서 잘 들고 다닙니다 아쉬운 점이 있다면 앞에 작은 포켓이 없다는 거큰 수납 공간만 세칸이에요 뭐 그래도 쓰는데는 큰 불편함 없어유
# 76.29% 확률로 부정 리뷰입니다.
#
# 가방 크기랑 디자인 다 너무 마음에 들어요ㅠㅠ 믿고사는 마크곤잘레스
# 55.23% 확률로 긍정 리뷰입니다.
#
# 크기도 적당하고 무난하게 매고 다니기 좋아여지퍼가 조금 아쉬울 뿐
# 66.32% 확률로 부정 리뷰입니다.
#
# 수납공간이 부족하다는 후기가 많았는데 저는 부족하다고 못 느껐어요
# 51.10% 확률로 긍정 리뷰입니다.
#
# 학교 다닐때 전공책 노트북 등 무거운거 막 넣고 다니려고 샀는데 아직 처지는 것도 없이 튼튼하게 잘 메고 다녀요
# 56.92% 확률로 부정 리뷰입니다.
#
# 수납공간도 넉넉하고 가방이 세로가 엄청길어요 그리고 안쪽에 오렌지색 포인트도 좋아요
# 74.80% 확률로 부정 리뷰입니다.
#
# 개인적으로 수납공간 많은걸 좋아하는데 그거에 비해선 심플하게 구성되어있는 주머니가 아쉽긴 합니다 하지만 겉에 디자인이 너무 예쁘고 뭔가 가방이 타원형같아서 귀여워요 헝헝 추천드려요
# 59.06% 확률로 부정 리뷰입니다.
#
# 가볍고 수납공간도 널널하고 여러모로 좋네요ㅎㅎ잘 매고 다니고 있습니당
# 75.27% 확률로 긍정 리뷰입니다.
#
# 안 유명 해졌으면 좋겠어요ㅠㅠㅠㅠ 진짜 흔해지는거 너무 싫어ㅠㅠ근데 진짜 예뻐요ㅠㅠㅠ
# 82.25% 확률로 긍정 리뷰입니다.
#
# 디자인도 일단 예쁘고 가방 속 색이 오렌지 색이여서 진짜 맘에 들었어오 수납도 생각보다 많이 됨 등에 닿는부분 어깨끈 푹신합니당
# 69.46% 확률로 긍정 리뷰입니다.
#
# 백팩 필요했었는데 크고 짐도 넉넉히 들어가요 세 군데로 나눠져 있어서 지퍼를 많이 열어야하지만 예뻐서 괜찮아요 안에 오렌지 색도 넘예쁨
# 92.14% 확률로 부정 리뷰입니다.
#
# 누가 메도 이상하지 않을 정도의 적당한 크기넉넉한 수납공간앞쪽에 귀여운 새가 킬링포인트
# 86.11% 확률로 부정 리뷰입니다.
#
# 일단 무겁지 않고 맷을때 편하게 잡아주는 느낌이에요 주 기다려서 받은 보람이 있어요 아주 이쁩니다
# 72.05% 확률로 부정 리뷰입니다.
#
# 구매하자마자 품절떠서 너무 좋았어요앞으로 잘 매고 댕길것 같아요가방앞에 써져있는 마크가 포인트가되는것같아서 더 이쁜것같습니다
# 85.51% 확률로 긍정 리뷰입니다.
#
# 가방도 크고 수납공간도 넉넉해서 개강하면 들고 다니기 너무 좋을 것 같아요 디자인도 이쁘고 너무 좋습니다
# 86.81% 확률로 긍정 리뷰입니다.
#
# 엄청 고민한 가방인데 너무 예뻐여 ㅠㅠ 가방은 엄청커서많이 넣을수는 있지만 자잘자잘한 수납공간은 별로 없어요 ㅠㅠ 밑에 판  같은게 없어서 쓰러진다는 후기가 있었는데 그 느낌이 뭔지도 알 것 같았습니다 하지만 너무 예뻐서 이해가 된 상품이에요
# 70.27% 확률로 긍정 리뷰입니다.
#
# 별로 안 흔한 가방 찾고있었는데 크기도 적당하고 수납공간도 넉넉하고 너무 이뻐용
# 73.95% 확률로 긍정 리뷰입니다.
#
# 수납 공간 큰 백팩을 찾고 있었는데 공간도 되게 넓고 재질도 좋고 디자인도 예뻐용 추천 합니다
# 76.41% 확률로 긍정 리뷰입니다.
#
# 가방 자체가 엄청 튼튼하고 수납 자체가 많아서 누구나 들기 좋을 거 같아용
# 66.03% 확률로 긍정 리뷰입니다.
#
# 진짜 마크 곤잘레스 예뻐요 잘산것 같아요 수납공간도 넉넉하고 안에 색이 넘 예뻐요  주황이 색감 굿 꼭 사세요 크기도 딱좋아요 좋은 제품 감사합니당 ㅎ ㅎ
# 91.15% 확률로 긍정 리뷰입니다.
#
# 작을까 봐 걱정했는데 진짜 크기 딱이에요 ㅜㅠ 대학 가서 매려구 샀습니다 진짜 안 부분이 주황색인 게 너무 귀여워
# 97.24% 확률로 긍정 리뷰입니다.
#
# 가방 생각보다 수납공간이 넉넉하고 가방 안에도 주황색이랑 너무 이쁩니다 흔한편도 아니라 좋네요 남자친구도 사주려구요
# 90.11% 확률로 긍정 리뷰입니다.
#
# 수납 공간도 많고 디자인도 이쁘네요 또 노트북 수납공간도 있어서 대학생이 쓰기에도 좋은 거 같아요
# 85.56% 확률로 긍정 리뷰입니다.
#
# 가방수납공간 매우큼 큰것만 개 지퍼가 좀 빡빡하지만 충분히 사용 ㄱㄴ튼튼함
# 55.04% 확률로 부정 리뷰입니다.
#
# 후기에 크다고 나와있어서 걱정했는데 일인데 적당하구 완전 이뻐요
# 89.95% 확률로 부정 리뷰입니다.
#
# 배송도 빠르구 수납공간도 넉넉해요 진짜 마꼼 최공
# 84.42% 확률로 긍정 리뷰입니다.
#
# 고등학교 학년 남학생 키에 예쁜 착용감의 가방입니다수납공간이 주황이라 포인트도 되고 검은가방 앞면의 흰 글의 영문로고도 고급져보입니다
# 76.41% 확률로 긍정 리뷰입니다.
#
# 그냥 사진으로봐도 이쁜데 매고다녀도 너무너무 이쁩니다
# 74.85% 확률로 부정 리뷰입니다.
#
# 크기가 조금 크지만 딱좋아요 글씨가 너무 튈것같아서 좀 고민했는데 실제로는 너무 예쁘네요 수납공간도 좋아요
# 95.43% 확률로 긍정 리뷰입니다.
#
# 사진으로 보는것보다 실물이 더 예쁩니다 근데 생각보다 커서 놀랬어요제가 인데 거의 제 엉덩이까지 오더라고요 수납공간은 되게 넓은데 안에 공간이 별로 안나눠져 있어서 쪼금 아쉽긴 한데 그래도 예뻐서 좋아요 그리고 지퍼가 좀 빳빳해요 참고 하세요
# 63.30% 확률로 긍정 리뷰입니다.
#
# 믿고 사는 브랜드 인것 같네요 다른 하자 없이 잘 왔습니다 ㅎㅎ
# 68.53% 확률로 긍정 리뷰입니다.
#
# 백팩을 오랜만에 사보는데 잘산거같아요 노트북도 잘 들어가고 내부 수납이 복잡하게 많지 않아서 좋습니다 등쿠션도 있어서 편하네요 예뻐요
# 71.15% 확률로 긍정 리뷰입니다.
#
# 여자친구가 샀는데 완전 만족해해여 가방 이쁘고 귀여워요 굿굿
# 97.35% 확률로 부정 리뷰입니다.
#
# 저렴하고 이쁘고 수납공간도 꾀나 충분해서 만족합니다
# 79.26% 확률로 긍정 리뷰입니다.
#
# 다른 후기에서 너무커서 엉덩이를 친다는 글을 보고 너무 커서 계속 엉덩이 치면 불편할것 같아서 살까말까 고민 많이 했었는데 막상 받아서 메보니까 저한테는 딱 제가 원하던 크기더라구요 엉덩이 치지도 않았구요요즘 일반적으로 메고다니는 백팩크기인 것 같아요키 인데 딱 엉덩이바로위까지 왔습니다진짜 가방 개이쁘고요 제발 아무도 사지마요 흔해지는거 싫어요ㅠ더보기
# 73.82% 확률로 긍정 리뷰입니다.
#
# 인데 길이도 딱 괜찮고 글씨가 넘 예쁘네요추천합니다
# 79.69% 확률로 긍정 리뷰입니다.
#
# 가방크기도 크고 디자인도이쁘고 백팩고민하시는분들 후기많이없어서 고민하실텐데 믿고사셔도될거같아요
# 55.51% 확률로 부정 리뷰입니다.
#
# 배송도 엄청 빠르고 가방도 너무 예뻐서 만족해요기준 등 다 덮고 엉덩이부근까지 내려오구요가슴버클도 편합니다내부가 주황색이라서 더 좋아요추천합니다 고민은 배송을 늦출 뿐
# 81.76% 확률로 부정 리뷰입니다.
#
# 가방너무 이뻐서 고민없이 바로 질렀는데 생각치도 못하게 불편한 점이있네요ㅠ 가방아래가 바깥으로갈수록 올라사는 사선모양이라 바닥에 세워놓으면 픽 쓰러져용ㅠ 이것만빼면 실물깡패 존예백팩이에요 맬때도 완전편하고 배송도빠르고 좋습니당
# 69.78% 확률로 긍정 리뷰입니다.
#
# 안에 수납공간이 거의 없는게 단점인것같아요 그거빼곤 맘에 듭당 추석때문에 조금 걸렸지만 그래도 만족합니다
# 56.86% 확률로 부정 리뷰입니다.
#
# 진짜 예쁘네요 실물이 더 이쁜거같아요크기도 딱좋고 옆에 주머니랑 안쪽 주머니가 많아서 편할거같아요
# 96.64% 확률로 긍정 리뷰입니다.
#
# 배송도 생각보다 빨리오고 가방이 예쁫고 사이즈도 커서 아이가 좋아해요
# 69.35% 확률로 부정 리뷰입니다.
#
# 실제로 보니까 예쁘고 귀여워요 인씨템하나 득템했네요
# 85.74% 확률로 부정 리뷰입니다.
#
# 디자인도 예쁘고 키링도 귀여워서 다 좋은데 어깨끈 부분이 약간 부실하게 바느질되어 있더라구요 그것빼고는 다 마음에 들어요
# 71.75% 확률로 부정 리뷰입니다.
#
# 예버여 안 흔한 거 좋아해서 이거 샀는데 나밖에 안 들고 다녀서 좋음 근데 예뻐여 ㅎㅎ
# 72.17% 확률로 부정 리뷰입니다.
#
# 가방 이쁘네용 사이즈도 딱 적당합니다잘 쓰겠습니당ㅎ
# 61.62% 확률로 부정 리뷰입니다.
#
# 너무 금방 뜯어졌어요 내구성이 약한것같네요 그래도 로고는 예뻐요
# 68.54% 확률로 긍정 리뷰입니다.
#
# 고등 아들 선물로 사줬는데 실물이 완전 이뻐요튼튼하고 간지나네요
# 96.99% 확률로 부정 리뷰입니다.
#
# 천사인형이 맘에 쏙 듦별로 안 커보이는데 생각보다 다 들어감
# 58.43% 확률로 긍정 리뷰입니다.
#
# 무난하게 샀는데 수납공간 아쉬운거 빼고는 괜찮네용
# 77.34% 확률로 긍정 리뷰입니다.
#
# 좀 크고 무거워요그래도 수납공간이 많아 유용해요
# 76.09% 확률로 부정 리뷰입니다.
#
# 가방 자체 무게가 좀 있어서 약간 무겁긴 한데 괜찮아요달려있는 인형이 진짜 귀여워요ㅠㅠ
# 70.21% 확률로 긍정 리뷰입니다.
#
# 다른 브랜드는 너무 흔해서 고민하다가이걸로 선택했는데 후회 없습니다
# 58.13% 확률로 부정 리뷰입니다.
#
# 친구 생일선물로 준 가방 예약기간인 월 말 훨씬 빨리 받아서 중순쯤 받아 선물 하고 이제야 리뷰 하네요 ㅎㅎ친구는 말도 할 것 없이 너무나 좋아하고 현재까지도 너무 이뻐하면서 매고다니고 있습니다선물한 사람 기분 좋게 항상 매고 다니니 제가 다 행복하네여 ㅎㅎ엄청 이뻐요 가방에 물건 넣고도 이쁘구요 아주 만족합니다
# 64.32% 확률로 긍정 리뷰입니다.
#
# 예뻐요키링이 너무 귀엽네요선물보냈는데 대 만족이랍니다
# 92.45% 확률로 부정 리뷰입니다.
#
# 같이 받은 키링이 포인트라 너무 좋아요 물건 많이 넣어도 가방 모양이 크게 달라지지 않아서 좋습니다
# 71.88% 확률로 부정 리뷰입니다.
#
# 배송도 빠르고 좋아요 모든 옷에 아주 잘어울려요
# 57.28% 확률로 긍정 리뷰입니다.
#
# 생각보다 가방이 좀 컸어요 그래도 노트북이랑 책 진짜 많이 넣어도 튼튼합니다 생각보다 깊어서 놀랐어요
# 89.42% 확률로 긍정 리뷰입니다.
#
# 사진으로보는것보다 훨씬 커요수납공간도 넉넉해요무거운감은 있습니다 ㅜㅜ 하지만 예뻐요
# 58.50% 확률로 긍정 리뷰입니다.
#
# 다 너무 좋은데 지퍼가 좀 빡빡하다는게 아쉬워요 근데 계속 쓰다보면 괜찮아질것같아요
# 99.65% 확률로 부정 리뷰입니다.
#
# 디자인 크기 생각보다 더 이쁘고 넉넉해서 맘에듭니다
# 77.23% 확률로 부정 리뷰입니다.
#
# 넘 이뻐요공간 수납도 좋고 사이즈도 적당하고 좋아요
# 83.02% 확률로 긍정 리뷰입니다.
#
# 디자인 예뻐요 근데 수납 공간은 넓은데 작은 물건들 담는 주머니는 하나밖에 없네요 후기 보니까 가방끈 약하다는 말이 많아서 조심히 써야겠어요
# 62.76% 확률로 긍정 리뷰입니다.
#
# 수납공간도 넓고 학교책가방용으로 샀는데 디자인도 이뻐서 추천해요
# 68.07% 확률로 긍정 리뷰입니다.
#
# 수납공간도 많고 디자인이 너무 이쁘네요 이벤트로 오는 인형도 너무 이뻐요
# 89.41% 확률로 긍정 리뷰입니다.
#
# 길다고 그래서 걱정했는데 메고 다닐 때 불편하진 않아요
# 71.55% 확률로 긍정 리뷰입니다.
#
# 딸래미 대학 입학해서삿는데 사이즈 아주 적당하고예쁘네용
# 77.20% 확률로 부정 리뷰입니다.
#
# 수납공간도 많고 달려오는 키링도 너무 귀여워요
# 66.87% 확률로 부정 리뷰입니다.
#
# 가방 내 공간도 넉넉하고디자인도 너무 예뻐소 좋습니당
# 95.07% 확률로 긍정 리뷰입니다.
#
# 무난무난하게 잘들고다닐거같아요 추천합니다
# 50.79% 확률로 긍정 리뷰입니다.
#
# 이게 이제 내가 쓸 가방입니당 오홍홍이뿝니다아
# 73.83% 확률로 긍정 리뷰입니다.
#
# 넉넉한 수납함과 평범하지 않은 포인트 예뻐요굿
# 56.74% 확률로 긍정 리뷰입니다.
#
# 디자인도 이쁘고 들고다니기에 크기도 적당합니다
# 58.64% 확률로 긍정 리뷰입니다.
#
# 좋아요좋아요 좋아요좋아요좋아요좋아요 좋아요
# 95.42% 확률로 부정 리뷰입니다.
#
# 대학생 백팩으로 추천합니다 일단 바나나가 무척 귀엽습니다
# 65.62% 확률로 부정 리뷰입니다.
#
# 생각 외로 사이즈가 적당해서 수납도 좋고 휴대성도 좋아요
# 82.98% 확률로 긍정 리뷰입니다.
#
# 달려있는 인형이 귀엽고 가방도 들고다니기 편합니다
# 55.81% 확률로 긍정 리뷰입니다.
#
# 안에도 넉넉하고 데일리로 들고다니기 너무 좋아요
# 84.15% 확률로 부정 리뷰입니다.
#
# 마크 곤잘레스 가방 짱짱 예뻐요 오래 기다렸는데 만족합니다
# 53.09% 확률로 긍정 리뷰입니다.
#
# 가방 엄청나게 예쁘고 노란색 인형이 포인트로 있어서 너무 좋아요 사길 잘한 것 같아요
# 84.48% 확률로 긍정 리뷰입니다.
#
# 가방 메기 편하고 좋습니당수납공간도 적당해서 좋아요
# 86.83% 확률로 긍정 리뷰입니다.
#
# 대학생 백팩 고민하다가 우연히 보고 샀는데 배송도 빠르고 실물이 진짜 이쁩니다 너무 마음에 들어요
# 67.76% 확률로 긍정 리뷰입니다.
#
# 사진 보다 실물이 훨씬 예쁩니다 다양한 스타일에 두루두루 어울려서 만족스럽습니다
# 73.71% 확률로 부정 리뷰입니다.
#
# 배송이 예상보다 빨리와서 너무 좋았어요 거의 주 일찍 온듯 책 한가득 담기에도 좋고 내구성이나 물에 잘 젖지않는 소재도 아주 만족스럽습니다
# 87.34% 확률로 긍정 리뷰입니다.
#
# 맨날 이것만 들고다닙니다 수납공간 넉넉하고 귀여워유 키링이 짱짱귀여움
# 73.05% 확률로 부정 리뷰입니다.
#
# 디자인도 너무 예쁘고 가볍고 좋아요 인형도 귀여워요
# 64.16% 확률로 부정 리뷰입니다.
#
# 선물 주려고 산건데 예쁘네요 생각보다 바나나가 컸어요 여분 바나나도 하나 더 있었으면 좋겠어요ㅎㅎ
# 94.17% 확률로 부정 리뷰입니다.
#
# 딱 캐주얼하게 맨투맨에 청바지나 그렇게 입었을때 입으니 엄청 이뻐요 ㅎㅎ
# 93.02% 확률로 부정 리뷰입니다.
#
# 예쁘고 마음에 들어요 무엇보다도 가격이 착합니당
# 92.79% 확률로 부정 리뷰입니다.
#
# 수납공간 넉넉하고 같이 온 키링도 너무 귀여워서 만족하며 사용중입니다
# 60.04% 확률로 긍정 리뷰입니다.
#
# 가방도 예쁘지만 키링 때문에 더 끌려서 샀는데 너무 만족해요
# 69.72% 확률로 부정 리뷰입니다.
#
# 편하고 예쁩니다 스타일낼때도 활용가능할 것 같아요 굿굿 만족
# 79.47% 확률로 긍정 리뷰입니다.
#
# 내가 아거 보고 아 전나 내꺼다 싶어서 바로 결제하고 샀는데 하 ㅋ 참 ㅋ 진짜 개예뻐요 올바른 소비 도장 쾅쾅
# 87.71% 확률로 긍정 리뷰입니다.
#
# 생각만큼 크고 가방 예뻐요 수납 공간 세 부분인데 지퍼가 조금 빡빡하네요 그래도 예쁘고 크니까 잘 쓰고 있습니다 ㅎㅎ
# 75.97% 확률로 부정 리뷰입니다.
#
# 진짜 진짜 이뻐요 사진보다 실물이 더 이뻐요특히 키링이 너무 귀엽네용ㅋㅋ
# 96.21% 확률로 긍정 리뷰입니다.
#
# 감사합니다 아주 맘에 들어요아이가 더 좋아하네요
# 94.40% 확률로 부정 리뷰입니다.
#
# 노트북이 인치라 들어갈까 걱정했는데 넉넉하게 들어가요
# 82.22% 확률로 부정 리뷰입니다.
#
# 오래오래기다리다 받았죠ㅎ그래도넘넘예뻐서 유쾌상쾌
# 84.75% 확률로 부정 리뷰입니다.
#
# 상품도 이쁘고 특히 인형이 찐 귀여워서 좋아용 최고
# 69.46% 확률로 긍정 리뷰입니다.
#
# 동생이 필요하다고 해서 샀는데 아직까지 잘 메고 다니고 편하대요
# 51.41% 확률로 부정 리뷰입니다.
#
# 바나난지 엔젤인지 조옹ㅇ라 귀여움 수납공간도 잘 나뉘어져 있어서 좋음
# 89.81% 확률로 긍정 리뷰입니다.
#
# 크기도 넉넉하고 디자인도 예쁩니다 추천드려요
# 52.03% 확률로 부정 리뷰입니다.
#
# 너무너무 좋아요 생각보다 크고 그리고 무겁지 않습니다
# 65.44% 확률로 긍정 리뷰입니다.
#
# 처음 배송왔을땐 작아보였는데 짐 넣고 보니까 엄청 크네요 수납공간도 넓고 많습니다 강추합니다
# 98.38% 확률로 긍정 리뷰입니다.
#
# 번째로 산 가방인데 가성비대비 수납공간 많고 나쁘지 않음
# 92.82% 확률로 긍정 리뷰입니다.
#
# 키링은 말도 못하게 너무 귀엽고 가방도 커서 어깨 넓은 저도 어깨 좁아 보일 것 같아요 수납공간도 많아서 좋아요
# 77.52% 확률로 부정 리뷰입니다.
#
# 오래걸린거빼놓곤 아주맘에 듭니다 대학신입생 울딸이 좋아하구요
# 50.90% 확률로 부정 리뷰입니다.
#
# 그동안 백팩 산 것 중에 가장 맘에 든다고 말할 정도로 진짜 너무 마음에 들어요 수납 할 수 있는 공간도 넉넉하구 너무 좋아요 최고
# 79.17% 확률로 긍정 리뷰입니다.
#
# 수납 공간 넉넉하고 크기에 비해 가벼워서 너무 좋습니다 마크콘잘레스의 상징인 엔젤 키링도 정말 큼직하니 마음에 꼭 듭니다
# 72.81% 확률로 긍정 리뷰입니다.
#
# 무엇보다 키링이 너무 귀엽고 디자인도 진짜 이뻐요수납공간도 완전 많은데다 다 실용적인 것 같아서 좋아요 다만 지퍼를 열 때 윗덮개가 자꾸걸려서 뻣뻣한 느낌이 있어요
# 81.26% 확률로 긍정 리뷰입니다.
#
# 뒤에 마크곤잘레스 레터링이 깔끔하고 예쁜거 같네요
# 58.85% 확률로 부정 리뷰입니다.
#
# 너무 긔엽고 예뻐요 노란색 인형이 포인트가 돼서 맘에들어용
# 73.98% 확률로 부정 리뷰입니다.
#
# 빅로고 가방 사고 싶었는데 이 가방이 디자인이 제일 마음에 들어서 샀는데 만족합니다 사이즈도 크고 수납도 널널해요 중고학생분들이나 대학생분들이 매도 이쁠 거 같아요
# 90.47% 확률로 긍정 리뷰입니다.
#
# 전체적인 디자인이 맘에 듭니다특히 키링이 있어서 더 이뻐요
# 98.23% 확률로 부정 리뷰입니다.
#
# 가방이 약간 무거운편 인것같아요 수납공간은 진짜 넓고 좋아요
# 85.92% 확률로 긍정 리뷰입니다.
#
# 중딩아들이 신학기가방으로 쓰는데 좋아요다만 가방자체 무게가 무거워서 책이랑 들어가면 많이 무겁네요
# 59.43% 확률로 긍정 리뷰입니다.
#
# 중학교 다니면서 가지고 다니려고 샀는데 너무 이쁘고 저장공간도 많아요
# 96.50% 확률로 긍정 리뷰입니다.
#
# 가방 실물로 보니까 더 이쁜 것 같아요 인형이 너무 귀여워요
# 87.62% 확률로 부정 리뷰입니다.
#
# 가방이 너무 귀여워요 특히나 사은품으로 받은 바나나 인형이 젤로요
# 67.33% 확률로 부정 리뷰입니다.
#
# 항상 백팩 매고 다니면 한사람 엎고 다니는 기분인데 이거 쓰고 인분 들고 다니는것 같아요  그래서 더 편해짐 버스 탈때
# 97.84% 확률로 긍정 리뷰입니다.
#
# 딸이좋아하네요가방도크고수납도잘되요 맘에듭니다
# 94.66% 확률로 부정 리뷰입니다.
#
# 가방 살까 말까 고민을 많이 했는데 가방 진짜 이쁘고 키링이 진짜 너무 귀여워요 수납공간도 많아서 너무 좋아요
# 94.13% 확률로 긍정 리뷰입니다.
#
# 노트북 넣고 다니려고 샀는데 제일 큰 부분에 인치 파우치까지 해서 꽉 차네요 작았으면 큰일날 뻔 ㅠㅠ 예뻐요
# 98.19% 확률로 긍정 리뷰입니다.
#
# 새학기 고등학생 책가방으로 구입했어요가볍고 사이즈 넉넉하고 이뻐요키링이 포인트가 되서 좋아하네요
# 96.67% 확률로 부정 리뷰입니다.
#
# 큰 로고에 귀여운 인형까지 너무 만족하는 가방입니다 수납공간도 넉넉해서 노트북 넣어서 잘 메고 다니고 있어요
# 94.50% 확률로 긍정 리뷰입니다.
#
# 사진과 동일 고등가방으로 사용하려구 구입함 수납넉넉하구 만족합니다
# 98.96% 확률로 부정 리뷰입니다.
#
# 달린 인형이 꽂혀서 샀는데 너무 귀여워요 친구들도 탐내합니다 ㅠㅠ
# 83.39% 확률로 부정 리뷰입니다.
#
# 크고 평소에 데일리로 매고 다니기 좋아요 예쁩니다
# 83.18% 확률로 부정 리뷰입니다.
#
# 중학교 입학 가방으로 샀는데 이쁘고 커서 책도 넉넉히 들어가요
# 82.25% 확률로 부정 리뷰입니다.
#
# 되게 만족하구요 바나나 너무 기여워요 큐트큐트
# 87.04% 확률로 부정 리뷰입니다.
#
# 수나ㅂ공간 넉넉하고 가볍기도 진짜가벼움 키링도 존예
# 95.64% 확률로 긍정 리뷰입니다.
#
# 깔끔한 디자인에 수납공간 넉넉하고 가슴끈 매면 예뻐서 매일 책가방으로 메고 다닙니다 에어팟 달고다니기도 조아요
# 54.52% 확률로 부정 리뷰입니다.
#
# 노란색 포인트가 멀리서도눈에뜁니다패션의완성은 가방이네요
# 80.67% 확률로 긍정 리뷰입니다.
#
# 좋아요 도복 넣어 다니려고 샀어요 많이 들어가요
# 96.84% 확률로 부정 리뷰입니다.
#
# 딸이 고등학생이 되어서 새로 구입했는데같은 마크곤잘레스 제품 개를 며칠동안계속 고민하다가 결국 이 제품을 골랐는데배송도 빠르고 디자인도 이쁘고 키링도너무 귀엽네요 가방 매고 있는 뒷모습이아주 예뻐요 요즘 잘가지고 다닙니다만족하고 있어요 사은품 교통카드도좋아요
# 98.61% 확률로 부정 리뷰입니다.
#
# 크기도 적당하고 수납공간도 넉넉해서 좋습니다ㅏ 마크 곤잘레스 로고 인형 넘 귀여워요 ㅜ
# 67.02% 확률로 긍정 리뷰입니다.
#
# 검은색 가방 필요했었는데 좋아요 인형 너무 귀여워요
# 59.41% 확률로 긍정 리뷰입니다.
#
# 일단 수납공간이 많아서 편리하고 디자인도 튀지않고 깔끔해서 어떤 옷을 입어도 어지간하면 잘어울려요
# 52.30% 확률로 긍정 리뷰입니다.
#
# 가방 너무 이쁘고 크고 수납공간도 많아서 너무 맘에 들어요
# 68.52% 확률로 부정 리뷰입니다.
#
# 가방이 생각보다 커요엥간한 컴퓨터 본체 하나 들어갈 거 같아요
# 84.34% 확률로 긍정 리뷰입니다.
#
# 예뻐요 근데 좀 큰감이 있고 지퍼가 불편하더라구용
# 70.82% 확률로 부정 리뷰입니다.
#
# 옆에 달려 있는 바나나가 너무 귀여워요잘 메고 다닐 것 같아요 ㅎㅎ
# 92.52% 확률로 부정 리뷰입니다.
#
# 가방 이뻐서 샀는데 매일 애용중이에요 추천합니다
# 73.27% 확률로 부정 리뷰입니다.
#
# 학교 다닐 때 매일 들고 다닙니다 이쁘고 심플해서 좋아요
# 76.51% 확률로 부정 리뷰입니다.
#
# 가방자체가 아주 크진 않은데 수납력이 좋습니다 전체적으로 세개로 나뉘어진 공간에 각각 하기 좋아요 근데 천사모양 키링이 바로 고리부분이 부서졌어요 요게 포인트인데흐부엉
# 70.10% 확률로 긍정 리뷰입니다.
#
# 수납공간은 적지만 크기가 적당해서 웬만한건 다 수납가능해요
# 88.60% 확률로 긍정 리뷰입니다.
#
# 디자인도 훌륭하고 수납공간도 넉넉해서 좋아요근데 지퍼여는게 좀 힘드네요
# 64.68% 확률로 긍정 리뷰입니다.
#
# 생각보다 용량이 크고 메고 다닐만 하네요 나쁘진 않구만
# 50.35% 확률로 긍정 리뷰입니다.
#
# 덩치가 좀 있는 편이라 그런지 가방이 작아보이더라구요 ㅎㅎ 그래도 저 인형이 너무 귀여워서 만족스럽습니다
# 96.73% 확률로 부정 리뷰입니다.
#
# 입학선물로 선물 했는데 넘 좋아하네요 디자인도 넘 이쁘고 포인트로 주신 키링 또한 넘 이쁘네요
# 76.77% 확률로 부정 리뷰입니다.
#
# 수납공간도 많고 물건 안 놓을때는 그렇게 막 크지도 않아서 만족합니다
# 77.32% 확률로 긍정 리뷰입니다.
#
# 동생 새학기 가방으로 샀는데 마음에 들어하네요가방 소재도 탄탄하고 방수도 될거같아요
# 67.44% 확률로 긍정 리뷰입니다.
#
# 가볍고 사이즈도 크고 수납공간도 많아서 좋아요
# 78.19% 확률로 긍정 리뷰입니다.
#
# 너무 너무 이쁘네요사이즈 좋아 보여요내일 매고 나갈려구요
# 70.05% 확률로 부정 리뷰입니다.
#
# 생각보다 실물이 너무 예쁘네요 저 바나나는 너무 하찮고 귀여어ㅓ요 바나나 제일 맘에 드네요 그렇다거 가방이 맘에 안드는거 아니에요
# 98.13% 확률로 부정 리뷰입니다.
#
# 가방에 이것 저것 다 들어가고 수납공간 많아서 좋아요 그리고 귀욥
# 65.85% 확률로 긍정 리뷰입니다.
#
# 추천 합니다 학생용으로 여행용으로 모두 좋을 것 같습니다 보드 수납도 가능하고 적극 추천 합니다
# 97.99% 확률로 긍정 리뷰입니다.
#
# 가방이 좋아요 마크곤잘레스 답게 바나나 이뻐요
# 52.97% 확률로 부정 리뷰입니다.
#
# 노랑노랑한 엔젤키링이 포인트가 돼서너무 이쁘구수납공간도 많고 착용감도 편해요마감이 살짝 아쉽긴 했지만 ㅜ
# 94.85% 확률로 긍정 리뷰입니다.
#
# 가방이 전체적으로 예쁘네요 근데 생각보다 조금 작은 느낌이 있어요 수납공간이 많아서 좋아요
# 90.79% 확률로 긍정 리뷰입니다.
#
# 생각했던거랑 같아서 좋고 수납도 적절히 할수 있을거 같아서 좋아용
# 90.25% 확률로 긍정 리뷰입니다.
#
# 구매하자마자 바로 품절되버리는 클라쓰너무 이쁘고 여자친구가 좋아합니다
# 87.08% 확률로 부정 리뷰입니다.
#
# 좋네요 음 새학기준비하는데 안성맞춤입니다 하하
# 98.84% 확률로 부정 리뷰입니다.
#
# 디자인이 너무 맘에 들고 수납공간도 넉넉해서 만족스럽습니다 다만 가방 안에 무언가를 넣었을 때 가방 밑부분이 처져서 이 부분이 좀 아쉽습니다
# 62.61% 확률로 긍정 리뷰입니다.
#
# 중학생 아들이 아주 만족하면서 학교 학원으로 다니고 있습니다
# 79.32% 확률로 부정 리뷰입니다.
#
# 좋아요빠르고 좋아요 배송빠르고좋아요 ㅋㅋ 아 진짜 요
# 65.20% 확률로 긍정 리뷰입니다.
#
# 가방에 수납공간도 많아서 너무 유용하게 사용할 것 같아요 그리고 인형도 있어서 포인트로 너무 좋더라고요 너무 맘에 들었습니다
# 64.77% 확률로 부정 리뷰입니다.
#
# 새학기에 매고다니기 적당하고 좋은 것 같습니다 선물로도 딱이네요
# 94.55% 확률로 부정 리뷰입니다.
#
# 엔젤 너무 커여워서 정신놓고 샀는데짱짱커서 좋음 ㅎ
# 67.83% 확률로 부정 리뷰입니다.
#
# 이쁘고 괜찮은데 지퍼에 달린 스트링 당겨서 열려하면 잘 안열려서 지퍼까지 넉넉히 잡아야 잘 열려요
# 57.37% 확률로 긍정 리뷰입니다.
#
# 수납 공간도 많고 가방 자체가 좀 커요 그리고 인형 귀여워용
# 79.47% 확률로 긍정 리뷰입니다.
#
# 그냥 학생 분들 학교다니면서 매기 딱 좋습니다 굿
# 90.21% 확률로 긍정 리뷰입니다.
#
# 일단 가방 앞판에 글자가 크게 있는게 좋았고 같이 주는 마크 곤잘레스 인형이 너무 귀엽다
# 67.56% 확률로 긍정 리뷰입니다.
#
# 사이즈도 넉넉하고 무게도 가벼워서 학교에 가져가기 딱 좋아요
# 89.50% 확률로 부정 리뷰입니다.
#
# 수납공간이 넓어서 좋구용 책가방으로 딱 적당한거같아용
# 81.82% 확률로 긍정 리뷰입니다.
#
# 가방 너무 이뻐요 중학생아들에게 잘어울리네요
# 54.07% 확률로 긍정 리뷰입니다.
#
# 생각보다 넓이보단 높이가 높음단으로 나눠져 있는데 차라리 단이 나았을 듯법 과목은 워낙 두꺼워서 한 권밖에 안 들어감높이를 줄이고 책 넣는 곳 두께가 더 넓었으면 좋았을 듯항상 가방 꽉 채워 다니는 사람으로써 수납 공간은 많지만 책 넣는 곳이 좀 좁았음 가방의 목적과 본질이 약간 흐려진 것 같음 번째 매쉬칸이랑 번째칸은 정말 수납용인데 첫번째 노트북 수더보기
# 98.19% 확률로 긍정 리뷰입니다.
#
# 생각했던거랑 살짝 다르지만 바나나인형도 그렇고 예쁩니다 부담없이 메고다녀고 될거같아요 수납공간도 아주 많습니다
# 94.56% 확률로 긍정 리뷰입니다.
#
# 졸업선물로 샀는데 받은사람이 맘에 들어합니다
# 84.47% 확률로 부정 리뷰입니다.
#
# 그냥 너무 예뻐요 고민 하시는분들은 고민 안 하시고 바로 사세요 절대 후회 안 합니다
# 61.20% 확률로 긍정 리뷰입니다.
#
# 넉넉하고 공간이 커요 전공책과 노트북 들고 다니기에 적당할거 같습니다
# 95.67% 확률로 긍정 리뷰입니다.
#
# 조ㅎ아요 새학기 가방으로 학교가 너무 가고싶네오 키링도 귀엽습니다 제 얼굴보다더 이건 못참지 당장 사세뇨
# 93.41% 확률로 부정 리뷰입니다.
#
# 대학교 입학 기념으로 구매했는데 너무 예뻐요흐
# 92.03% 확률로 부정 리뷰입니다.
#
# 수납 공간은 넉넉하지만 칸이 나뉘어있진 않은 느낌이네요 디자인은 확실히 만족합니다
# 79.97% 확률로 긍정 리뷰입니다.
#
# 인치 노트북도 수납이 가능하다고 해서 샀는데 인치는 조금 무리가 있는 것 같아요ㅜㅜ
# 97.14% 확률로 긍정 리뷰입니다.
#
# 사이즈도 적당히 크고 가벼워서 좋아요잘 사용할께요
# 81.83% 확률로 부정 리뷰입니다.
#
# 사진보다 기엽고 수납공간도 넉넉하고 예쁩니다
# 79.35% 확률로 긍정 리뷰입니다.
#
# 이 바나나 인형이 엄청 귀엽고 앞에 똑딱이도 있어서 좋아요
# 51.67% 확률로 부정 리뷰입니다.
#
# 가방의 공간이 넓어 물건을 많이 담을 수 있고 가방 자체가 예뻐요
# 76.45% 확률로 긍정 리뷰입니다.
#
# 아들이 너무 마음에 들어하네요어디든 잘 어울려서 구매 잘 한듯 합니다
# 96.17% 확률로 부정 리뷰입니다.
#
# 조카 졸업 선물로 샀는데 조카 많이 좋아했답니다
# 98.05% 확률로 부정 리뷰입니다.
#
# 이뻐용 근데 지퍼열고닫고 할때좀 걸리는게 불편하긴해용
# 88.61% 확률로 긍정 리뷰입니다.
#
# 수납공간 생각보다 크게크게 많이있어여 무엇보다 빠나나가 너무기여워요 크기도 적당하고 짱잘산듯합니다
# 65.15% 확률로 긍정 리뷰입니다.
#
# 새학기 가방 찾다가 골랐는데 이쁘네요 인형 귀여워요
# 94.79% 확률로 부정 리뷰입니다.
#
# 저 바나나 새 에 반해서 샀는데 의외로 가방 색감도 괜찮고 맘에 들어요 다만 좀 빳빳한 재질이라서 처음 지퍼 열때 소리가 좀 큰데 그래도 쓰다보면 괜찮겠죠
# 86.78% 확률로 긍정 리뷰입니다.
#
# 가방 크고 넓어서 책이 많이 들어가고 디자인도 너무 예뻐서 마음에 들어요
# 77.80% 확률로 부정 리뷰입니다.
#
# 공간도 넓고 좋네요 가방칸수도 많고 바나나 넘귀여워용
# 89.42% 확률로 긍정 리뷰입니다.
#
# 등판이 생각보다 크니까 잘 고민하고 사시길 바래요 디자인은 대박입니다
# 87.97% 확률로 긍정 리뷰입니다.
#
# 수납공간 넉넉하고 가벼워요 키링이 귀여워서 좋은것같아요
# 51.95% 확률로 부정 리뷰입니다.
#
# 평소에 원래 마크 곤잘레스 좋아해서 마음에 드는 제품이었네여
# 99.34% 확률로 부정 리뷰입니다.
#
# 너무 예쁘기도 하고 수납공간이 널널한 가방이 필요해서 샀는데 기대에 미치는 가방입니다 키링으로 주신 엔젤 키링도 너무 귀엽고 포인트로 딱이에요
# 90.97% 확률로 긍정 리뷰입니다.
#
# 엔젤키링이 갖고 싶어서 샀는데 생각보다 사이즈도 넉넉해서 괜찮은 것 같아요
# 59.84% 확률로 긍정 리뷰입니다.
#
# 만족스럽습니다 앞부분 지퍼가 살짝 빡빡한 감이 있지만 어차피 책만 넣고 다닐거라 상관없을거 같어요
# 85.67% 확률로 긍정 리뷰입니다.
#
# 가방이 엄청 가볍고 수납할 공간도 많아서 좋구여 디자인도 너무 좋구요 귀여워요
# 53.71% 확률로 부정 리뷰입니다.
#
# 가방 크기 넉넉하고 디자인도 예뻐서 맘에들어요
# 89.61% 확률로 부정 리뷰입니다.
#
# 개학이 싫었지만 이 백팩 사고 난 뒤로부터는 개학이 살짝 설레넿ㅎㅎ
# 92.76% 확률로 긍정 리뷰입니다.
#
# 예뻐요덩치가 작아서 너무 크면 어쩌지 했는데 나름 잘 맞아요가방 재질이 약간 딱딱해서 좀 어색하던데 좀 더 써봐야 알 것 같아요귀엽고 학교에서 쓰기 좋을 것 같아요
# 98.49% 확률로 부정 리뷰입니다.
#
# 크기가 커서 많이 들어갈 것 같고 엔젤키링이 귀여워요 그리고 몰랐는데 로고가 빛 반사하는 재질이에용 좋아요
# 82.33% 확률로 부정 리뷰입니다.
#
# 딸 선물로 구매했는데 마음에 들어하니 다행입니다
# 79.71% 확률로 부정 리뷰입니다.
#
# 가방 예쁘고 공간도 적당히 넓어서 검은 옷이랑 잘 어울립니다
# 77.62% 확률로 긍정 리뷰입니다.
#
# 디자인도 너무예쁘고 가벼워서 잘 매고 다닐수 있을것 같아요
# 56.71% 확률로 부정 리뷰입니다.
#
# 엔젤 키링 너무 귀엽네요 노트북 수납할 공간두 있고 전체적으로 괜찮은거같아요
# 54.24% 확률로 부정 리뷰입니다.
#
# 가방이 커서 이것저것 넣기 좋아요 잘쓰겠습니다
# 72.99% 확률로 부정 리뷰입니다.
#
# 중학생 여자아이에게 클까봐 여러번 고민하고 샀는데 괜찮네요 독특한 디자인이구요
# 80.66% 확률로 부정 리뷰입니다.
#
# 수납공간 적당하고 착용감도 편해서 편안하게 하고 다닐 수 있을거같아요
# 80.97% 확률로 긍정 리뷰입니다.
#
# 가방 사진이랑 그대롱고 가방이 생각했던거보다 이쁜거같아여
# 80.64% 확률로 긍정 리뷰입니다.
#
# 진짜 너무 예뻐요 티머니 카드까지 주니 더 좋은것 같아요 고민 말고 사세요
# 77.03% 확률로 긍정 리뷰입니다.
#
# 엔젤 키링이 마음에 들어서 사봤는데 실물로보니 더귀엽네요 가방 수납공간도 짱짱하고 디자인도 이쁩니다
# 89.92% 확률로 긍정 리뷰입니다.
#
# 남자친구가 선물해줬는데 아주 마음에 들어용하
# 95.72% 확률로 부정 리뷰입니다.
#
# 사이즈도 적당하고 메기 편합니다 악세사리도 귀엽네요
# 86.36% 확률로 부정 리뷰입니다.
#
# 생각보다 작을 줄 알았는데 수납공간도 많고 그렇게 크지도 않아요
# 94.50% 확률로 긍정 리뷰입니다.
#
# 생각보다 크기가 커요 달려있는 인형이 너모 귀엽네요ㅠㅠ
# 50.38% 확률로 긍정 리뷰입니다.
#
# 기대 정말 많이 하고 샀는데 기대만큼 정말 예쁩니다 엉엉 사은품도 너무 귀여워요 인형도 너무 귀여워요 ㅠㅠ
# 51.55% 확률로 긍정 리뷰입니다.
#
# 지퍼가 불편한거 빼고는 만족합니다 크기도 크고 디자인도 이뻐요
# 85.39% 확률로 긍정 리뷰입니다.
#
# 수납공간도 적당하고 무게도 적당해서 잘 쓸 것 같아요
# 73.30% 확률로 긍정 리뷰입니다.
#
# 아주 좋고 잘 쓰고 있습니다 이쁘고 크기도 커서 좋네여
# 82.79% 확률로 부정 리뷰입니다.
#
# 엄청 큽니다 노트북이랑 책 충분히 넣어도 됩니다
# 54.14% 확률로 부정 리뷰입니다.
#
# 수납공강 충분하고 완전 이뻐요 키링도 귀엽고 사은품으로 온 티머니 카드도 완전 예쁩니당
# 65.18% 확률로 긍정 리뷰입니다.
#
# 이번에 고등학교 올라가서 엄마가 사줬는데 너무 예뻐요
# 67.67% 확률로 부정 리뷰입니다.
#
# 전 가방이 작아서 좀 큰걸 원했는데 용량도 넉넉하고 무엇보다 이쁘네요
# 82.57% 확률로 긍정 리뷰입니다.
#
# 기대감이 컸는데 확실하게 만족시켜줬습니다 수납공간 걱정했는데 넓어서 좋았고 바나나인형도 너무 귀여워요
# 94.54% 확률로 부정 리뷰입니다.
#
# 수납공간도 넉넉하고 특히 바나나모양 인형이 너무 귀엽네요 포인트 되구요
# 89.91% 확률로 긍정 리뷰입니다.
#
# 새학기용으로 구입했어요 아이가 귀엽다고 좋아하네요 사이즈도 책가방으로 적당하고 튼튼해 보여요 할인 받아서 질 구입했습니다
# 99.57% 확률로 부정 리뷰입니다.
#
# 가격도 좋고 수납할 수 있는 공간이 많아서 좋아요새학기에 쓰기 딱 젛은 가방 추천 ㅎ
# 73.83% 확률로 긍정 리뷰입니다.
#
# 만족합니다 크기도 넉넉하고 키링이 참 맘에드네옹
# 94.26% 확률로 부정 리뷰입니다.
#
# 가방이 귀엽고 안에 많이 들어갈 수 있을 거 같아서 좋아요
# 67.58% 확률로 긍정 리뷰입니다.
#
# 동생 입학선물로 사줬는데 좋아하네요 만족스럽스ㅂ니다
# 57.18% 확률로 긍정 리뷰입니다.
#
# 전에 쓰던 가방이 너무 작고 무거워서 새로 샀는데 수납공간도 많고 넓어서 많이 들어가고 좋네요 고 잘 버틸 수 있을 것 같아요
# 93.64% 확률로 긍정 리뷰입니다.
#
# 앞에 로고가 진하게 그려저 있어요 키링도 같이온거 귀여워요
# 97.69% 확률로 부정 리뷰입니다.
#
# 잘 쓸것같네요수납공간도 충분하고 노트북도 잘들어 갑니다
# 66.02% 확률로 긍정 리뷰입니다.
#
# 디자인도 이쁘고 좋네요 대학교다닐때 잘쓸거같아용ㅎ
# 86.22% 확률로 긍정 리뷰입니다.
#
# 가방은 처음 사봤는데 맘에 드네요 달려있는 인형도 귀여워요
# 70.80% 확률로 부정 리뷰입니다.
#
# 가방이 세로로 길어서 그런지 등에 싹 감기는게 편안하공요ㅋㅎㅋㅎ 책을 넣어도 위에 공간이 엄청 남아서 옷을 넣고 다녀도 좋겠어요
# 96.25% 확률로 부정 리뷰입니다.
#
# 수납공간 많고 크기도 적당하고 무엇보다 키링이 귀욤 깜찍합니다
# 71.22% 확률로 긍정 리뷰입니다.
#
# 가방이 생각보다 크고 수납공간이 많아서 좋네요옆에달린 바나나도 귀엽고요
# 85.68% 확률로 긍정 리뷰입니다.
#
# 동생 고등학교 가방으로 샀는데 넉넉하고 괜찮네용
# 59.75% 확률로 긍정 리뷰입니다.
#
# 사이즈도 크고 물건도 많이 들어가서 좋아요작은 포켓이 조금 더 있어도 될거 같다는 느낌이 드네요
# 96.05% 확률로 부정 리뷰입니다.
#
# 제 맘에 쏙드는 가방이에요 가방 필요하신 분들께 강추드립니다
# 96.04% 확률로 부정 리뷰입니다.
#
# 생각보다 넉넉해서 좋고색깔이 흠집없이 깔끔해요
# 97.92% 확률로 부정 리뷰입니다.
#
# 수납공간이 엄청 많고 물건 전공책 권은 거뜬히 들어갈 수준으로 큽니다
# 70.11% 확률로 긍정 리뷰입니다.
#
# 사이즈가 큰 편이에요 세로로 길고 수납공간도 괜찮아요 지퍼 열기가 살짝 빡빡한 감이 있어요
# 96.58% 확률로 부정 리뷰입니다.
#
# 가볍고 신학기 맞이해서 구매 했는데 만족해요 좋아요
# 52.87% 확률로 부정 리뷰입니다.
#
# 수납공간이 넉넉해서 좋고 가방이 전체적으로 이쁘네요
# 59.08% 확률로 부정 리뷰입니다.
#
# 수납 공간 진짜 낭낭하고 실물이 갑입니다요 인형도 기엽네요
# 96.69% 확률로 긍정 리뷰입니다.
#
# 배송도 빠르고 젤 고민했던 노트북 인치도 무난하게 들어갑니다 잘쓸께요
# 61.28% 확률로 긍정 리뷰입니다.
#
# 넘 예뻐요 실물이 훨 낫네요 큰가방 원했는데 진짜 딱 제가 원하던 크기 좋은 가격에 좋은물건 잘 샀어요
# 64.97% 확률로 긍정 리뷰입니다.
#
# 아아주 맘에듭니다 색상도 아주 맘에 듭니다베리굿
# 95.74% 확률로 부정 리뷰입니다.
#
# 마곤 바인드 백팩 너무 좋은데요 사은품도 장난아니에요 교통카트랑 스티커 너무 예뻐요 가방도 많이 쓸꺼고 교카도 잘쓸께요 친구들한테도 추천 해줘야겠습니다 짱
# 95.30% 확률로 부정 리뷰입니다.
#
# 이쁘고 사은품으로 교통카드 까지 주셔서 잘쓸게여
# 83.73% 확률로 부정 리뷰입니다.
#
# 상품을 받았을때 너무 새상품냄새가나서 좀 머리가 아프네요 수납공간도 생각보다 적어요 그래도 디자인은 이쁘네요
# 85.89% 확률로 부정 리뷰입니다.
#
# 고등학생인제 가볍고 수납도 많아 좋아요 실물도 예쁩니다
# 92.66% 확률로 긍정 리뷰입니다.
#
# 너무 예뻐요 마크 곤잘레스 로고도 이쁘고 인형도 이쁘네요
# 77.92% 확률로 긍정 리뷰입니다.
#
# 어 먼저노랭이가 너무 귀여웠구요또넉넉하구가성비가 좋은 거 같아요이렇게 하면 되나
# 50.37% 확률로 긍정 리뷰입니다.
#
# 처음에 좀 걱정했는데 수납공간도 많고 진짜 실물이훨씬이뻐요 후회안합니다
# 95.62% 확률로 긍정 리뷰입니다.
#
# 수납공간이 적절하고 크기도 제 몸이 커서 생각보다 적당합니다 이뻐요
# 52.04% 확률로 부정 리뷰입니다.
#
# 인형 존내 귀엽네뽀뽀딱대다른가방들보다 더 이쁜거같아요다들 이거사시길
# 83.53% 확률로 긍정 리뷰입니다.
#
# 가방 실물이 더 이뻐요 디자인도 깔끔하고 가벼워서 평소에 부담없이 잘 메고 다닐 수 있을 것 같아요 노란색 인형걸이가 있어서 그런지 가방이 더 발랄해 보여요
# 65.65% 확률로 부정 리뷰입니다.
#
# 가볍소 수납공간도 넉넉해서 좋아요 또 사은푼으로 달려온 인형도 귀여워서 좋아요
# 88.43% 확률로 긍정 리뷰입니다.
#
# 수납공간이 생각보다 넉넉해서 수납 걱정은 안될 것 같아요 사은품으로 티머니 카드랑 스티커를 제공해줘서 잘 샀다는 생각이 들었습니다 마크 곤잘레스
# 95.75% 확률로 긍정 리뷰입니다.
#
# 동생 입학선물로 구매했는데 공간도 많고 크기도 딱적당하고 가벼워요 저 바나나가 너무 귀여워서 훔치고 싶을만큼 너무 탐나네요
# 76.02% 확률로 부정 리뷰입니다.
#
# 정말 이뻐서 앵간한 코디엔 다 잘어울리네용 추천
# 92.42% 확률로 부정 리뷰입니다.
#
# 수납공간 괜찮고 사이즈도 크니 딱 좋네요 만족스러워요
# 53.61% 확률로 부정 리뷰입니다.
#
# 이틀만에 받았습니다가방도 너무 예쁘고 키링이 너무 맘에 드네여
# 98.22% 확률로 부정 리뷰입니다.
#
# 수납공간이 엄청 많고 깊어서 전공책 많이 넣을 수 있을 것 같습니다
# 61.52% 확률로 긍정 리뷰입니다.
#
# 가방에 물건을 많이 담을수 있고 예뻐서 너무 좋아요
# 82.70% 확률로 부정 리뷰입니다.
#
# 인터넷에서 구매하기전에 사진에서 본거랑 실물이 똑같네요 맘에 들어요 그리고 스티커 사은품도 맘에 들어요
# 77.59% 확률로 긍정 리뷰입니다.
#
# 인치 노트북이 들어갈 정도로 넉넉하고 스타일 좋아요
# 94.75% 확률로 부정 리뷰입니다.
#
# 가방 디자인 너무 예쁘고 같이 온 교통카드랑 스티커도 너무 예뻐요 잘 쓰겠습니다ㅏ
# 77.31% 확률로 부정 리뷰입니다.
#
# 생각보다 커서 놀랐고지퍼가 좀 매끄럽게 안열려서 아쉬웠어요 그래도 커서그런지 많이들어가구 수납공간도 적당해서 좋더라구요
# 94.05% 확률로 긍정 리뷰입니다.
#
# 완전 마음에 들어요 큰 사이즈 가방 원하시는 분 추천입니다
# 96.14% 확률로 부정 리뷰입니다.
#
# 로고 맘에들구요 인형 사은품으로 줘서 고맙습니다
# 62.89% 확률로 긍정 리뷰입니다.
#
# 수납공간이 엄청 넉넉하고 너무 좋아요 추천합니다
# 72.12% 확률로 긍정 리뷰입니다.
#
# 사은품도 너무 예쁘네요오ㅠㅠ 크기도 좋고 예쁘게 잘 사용할게요
# 79.01% 확률로 긍정 리뷰입니다.
#
# 이쁘고 귀엽고ㅎ 독서실 갈때나 강의 들으러갈때 잘 사용하겠습니다
# 99.53% 확률로 부정 리뷰입니다.
#
# 생각보다 크네요수납공간이 널널하긴 한데 자꾸 가방이 앞으로 쏟아져요 ㅠㅠ
# 79.95% 확률로 긍정 리뷰입니다.
#
# 커서 좋아요 칸이 많이 안 나눠져있긴하지만 넣어놓기 좋아요
# 75.54% 확률로 긍정 리뷰입니다.
#
# 가방 이쁘네요 별로 기대하지 않았는데 생각보다 아주 좋고 수납공간이 널널합니다
# 95.62% 확률로 긍정 리뷰입니다.
#
# 로고글씨가 예쁘네요 색감도 좋습니다추천합니다
# 74.91% 확률로 부정 리뷰입니다.
#
# 동생한테 선물했더니 아주 좋아하네요사진에서 본 그대로입니다 아주 만족스러워요
# 89.57% 확률로 부정 리뷰입니다.
#
# 검정색 바디에 작은 마크 곤잘레스 인형이 달려 있아사 너무 귀엽고 편해요
# 89.10% 확률로 부정 리뷰입니다.
#
# 생각보다 작은데 가벼워서 좋구여 인형 귀여워요
# 63.58% 확률로 긍정 리뷰입니다.
#
# 이쁘네요슬림한스타일이라 날씬한 아들한테 딱 이뻐요
# 84.40% 확률로 부정 리뷰입니다.
#
# 사진으로 봤던 것보다 실물이 훨씬 나아서 정말 마음에 듭니다 수납공간도 적당히 넓고 가방의 각이 잘 잡혀 있어서 좋네요 무엇보다 마크 곤잘레스 인형 진짜 너무 귀여워요ㅠㅠ
# 73.89% 확률로 긍정 리뷰입니다.
#
# 예뻐요 어디에 코디해도 잘 어울리구 달려있는 노랑노랑 인형 이 엄청 귀여워서 포인트 주기 좋아요
# 73.98% 확률로 긍정 리뷰입니다.
#
# 생각보다 크지않고 착용감도 정말 좋네요 ㅎㅎ 흔하지 않아서 만족스러워요
# 78.04% 확률로 긍정 리뷰입니다.
#
#  여자인데 이상하게 커보인다 이런 느낌 전혀 없고 안정감 있게 등도 딱 덮어줘요 만족합니당
# 95.82% 확률로 부정 리뷰입니다.
#
# 작은 수납 공간이 없어서 아쉽지만 가방 앞부분이 너무 예쁩니다 ㅠㅠ 다들 사세요
# 87.71% 확률로 긍정 리뷰입니다.
#
# 크기가 크기인 만큼 막 그렇게 가볍지는 않은거 같아요 그래도 모양이 예쁘고 수납공간도 넉넉해서 딱 좋은것 같아요 남자든 여자든 다 예쁘게 잘 쓸수있는 디자인이에요
# 53.18% 확률로 긍정 리뷰입니다.
#
# 정말 이쁘고 좋은거 같아요 수납 공간이 넓어서 진짜 좋은거 같아요
# 77.60% 확률로 긍정 리뷰입니다.
#
# 세로가 좀 길기는 한데 수납공간 많고 흔하지 않아서 좋ㅇ네요
# 93.91% 확률로 부정 리뷰입니다.
#
# 제 상체가 짧아서 그런걸수도 있는데 조금 길어서 가방 올려서 매고 다녀요ㅎㅅㅎ
# 98.24% 확률로 부정 리뷰입니다.
#
# 이건 뭐 정말 하나정돈 가지고 다녀야 할 가방인듯
# 56.86% 확률로 부정 리뷰입니다.
#
# 안에 공간 은근 커서 웬만하면 다 넣을수 있어요 가벼워서 좋아요
# 83.52% 확률로 긍정 리뷰입니다.
#
# 사이즈 괜찮고 질도 괜찮네요 자주 매지는 않을거 같네요
# 99.44% 확률로 부정 리뷰입니다.
#
# 가볍고 ㄹㅇ로 개이쁨 꼭 사세요 실물이 훨씬 낫네요 룰
# 97.11% 확률로 부정 리뷰입니다.
#
# 가방이 커서 수납하기 좋아요 그리고 뒤에 글자도 너무 에쁘게 잘 나왔어요 학교에 들고가도 좋아보이네요
# 62.73% 확률로 부정 리뷰입니다.
#
# 가방 디자인이랑 수납공간 및 사이즈는 넉넉해서 만족스러운데 내구성이 너무 떨어집니다
# 84.67% 확률로 긍정 리뷰입니다.
#
# 크기가 작을 줄 알았는데 생각보다 크고 수납공간도 적당해요
# 95.63% 확률로 긍정 리뷰입니다.
#
# 디자인도 예쁘고 수납 공간도 넉넉해서 노트북도 충분히 드가요
# 50.61% 확률로 부정 리뷰입니다.
#
#  키에 알맞는 크기인 가방이에요인생백팩입니다
# 91.30% 확률로 부정 리뷰입니다.
#
# 이쁘고 수납공간도 넓어요 전체적으로 딴딴하니 좋아요
# 64.43% 확률로 부정 리뷰입니다.
#
# 동생의 벌스데이 선물로 사줬는데 후회합니다 제 가방으로 살 껄너무 이뻐요 선물인데 뺏으면 안되겠죠ㅠ
# 89.52% 확률로 부정 리뷰입니다.
#
# 사고나서 거의 매일 들고다니고 있을정도로 좋아요
# 94.81% 확률로 부정 리뷰입니다.
#
# 쿠션감도 좋고 수납공간도 넉넉해서 좋아용 안에 노란색 안감도 너무 예뻐요
# 67.39% 확률로 긍정 리뷰입니다.
#
# 전 가방은 수납공간이 적어서 불편했는데 이건 생각보다 되게 넓어서 좋네여
# 85.60% 확률로 긍정 리뷰입니다.
#
# 너무좋아요세일할때사길너무잘했다고생각들어요짱짱
# 96.36% 확률로 긍정 리뷰입니다.
#
# 수납공간도많고 내피가 주황색이라 은근이쁘고 매면예뻐요
# 54.63% 확률로 부정 리뷰입니다.
#
# 고등학교 입학기념 가방 몇개 구입했는데 칙칙한 검정만 있는 제품들보다는 내부가 주황빛도는 색으로 되어 있어서 그런지 너무 칙칙하지도 너무 튀지도 않고 좋은 것 같아요
# 95.82% 확률로 부정 리뷰입니다.
#
# 제가 덩치가 있어서 혹시라도 가방이 작으면 어쩌지 생각했는데 굉장히 커서 만족합니다 가방도 너무 예쁨니다
# 89.26% 확률로 부정 리뷰입니다.
#
# 디자인이 진짜 마음에 들었어요근데 가방 끈 부분이 얼마 매지도 않고 무겁지도 않았는데 약간 끊어지려고 한거ㅠㅠ그래도 그거 말고는 진짜 잘 매고 있어요
# 80.96% 확률로 긍정 리뷰입니다.
#
# 이 가방 진짜 힙해요 실물이 진짜 너무 예뻐요 다들 사세요
# 95.18% 확률로 긍정 리뷰입니다.
#
# 너무너무 좋아요 마크곤잘 사랑해요 수납공간두 많아서 좋고 근데 별루 무겁게 안가지고 다닌거같은데 한 두달썻더니 약간 끊어질라구 실밥이 튀어올라잇더라구요 풉 푸핰어쩔수없죠
# 89.38% 확률로 긍정 리뷰입니다.
#
# 세로로 조금 긴거같긴한데 제가 키가커서 상관없는거같아요안감이 주황색이라 포인트가 되는것 같네욤
# 93.14% 확률로 부정 리뷰입니다.
#
# 다른 그냥 검정 가방보다 안에 색깔이 확 눈에 들어와 포인트로 좋은거 같습니다
# 96.10% 확률로 부정 리뷰입니다.
#
# 보기에도 이쁘고 실제로 써보니 수납공간도 무난하네요 커버낫은 너무 많아서 이 가방이 더 이뻐보이는듯
# 69.20% 확률로 부정 리뷰입니다.
#
# 수납공간 부족하다는 평이 있어 걱정했는데조그만포켓만 없을뿐 수납은 괜찮아여할인도 하는김에 여행때 쓸려고 샀는데 좋습니다
# 52.63% 확률로 긍정 리뷰입니다.
#
# 수납공간많고 디자인도 정말이뻐요 짐이많아도 들기편함
# 69.78% 확률로 긍정 리뷰입니다.
#
# 수납 공간이 많지 않다 들었는데 막상 와보니까 수납 공간도 많고 좋은거 같아요
# 76.66% 확률로 긍정 리뷰입니다.
#
# 작지 않을까 걱정했는데 생각보다 크고 딱맞아서  긋긋긋
# 94.26% 확률로 긍정 리뷰입니다.
#
# 너무 만족스럽게 잘 들고 이용중입니다매우 만족합니다
# 78.09% 확률로 긍정 리뷰입니다.
#
# 존예 일단 흔하지 않아서 너무 좋아요 안흔한게젤 최고 위아래론 큰데 보폭이 너무 좁아요 책 몇권 넣으면 필통 넣을 자리가 엊ㅅ어요 ㅠㅠㅠ
# 95.49% 확률로 부정 리뷰입니다.
#
# 마크곤잘레스 브랜드에 푹 빠져서 가방도 샀는데 아니나 다를까 정말 예뻐요  맨 마지막 수납공간이 위아래로 커서 책이 권정도만 들어가네요  평소에 많이 들고 다니는 편이 아니라서 충분히 만족합니다  예쁘고 마음에 들어요
# 76.16% 확률로 부정 리뷰입니다.
#
# 너무 이뻐용 ㅜㅜㅜ옷도 이쁘고 가방도 이쁘네요수납공간도 널널해서 넘 쪼앙용
# 88.27% 확률로 긍정 리뷰입니다.
#
# 동생 선물로 사줬는데 너무 좋아하네요ㅎㅎ로고도 진짜 예뻐요
# 78.39% 확률로 부정 리뷰입니다.
#
# 안 흔하고 등딱지 다 막아주는 가방 촤곱니다 넘 예쁨
# 95.15% 확률로 부정 리뷰입니다.
#
# 아주 좋습니다 원하던 디자인이라서 맘에드네요
# 92.77% 확률로 부정 리뷰입니다.
#
# 좋은 상품 좋은 가격에 구입했습니다 감사합니다
# 98.46% 확률로 부정 리뷰입니다.
#
# 동생 사줬ㅇ는뎅 예뿌네용 제가 매겠습니다 많이 파세여
# 83.66% 확률로 부정 리뷰입니다.
#
# 완전 예뻐여 사도 후회 안합니다 잘 쓰겠습니다감사해용
# 70.85% 확률로 긍정 리뷰입니다.
#
# 여자친구한테 선물했는데 너무 좋아합니다 만족해요
# 95.25% 확률로 부정 리뷰입니다.
#
# 수납공간 커서 괜찮네요 대신 주머니좀 크게 만들어주세요 굿
# 71.81% 확률로 긍정 리뷰입니다.
#
# 너무 이쁜데 작은 수납공간이 많이 없어서 조금 불편하네욤
# 94.71% 확률로 긍정 리뷰입니다.
#
# 크다는 평이 많았는데 확실히 크긴 커요 근데 막 감당 못하게 크고 그 정도는 아닙니당 수납 공간 적다는 얘기도 있던데 크게 불편함은 못 느꼈어요 디자인은 확실히 예뻐요  오렌지색 너모 쨍하고 귀엽고 맠곤 로고도 예쁩니당
# 93.38% 확률로 부정 리뷰입니다.
#
# 제가 딱 원하던 큰 사이즈에요 앞으로 엄청 자주 메고 다닐듯합니당
# 99.13% 확률로 부정 리뷰입니다.
#
# 할인해서 샀는데 나쁘지 않네요 크기도 적당하고 편해요
# 70.88% 확률로 부정 리뷰입니다.
#
# 고민하다 샀는데 예뻐요 맘에들어요 ㅋㅋ 흔하지않고 좋은것같어요
# 88.66% 확률로 부정 리뷰입니다.
#
# 예뻐요 실물이 더 예쁩니다패셔너블한 가방이네용
# 63.48% 확률로 긍정 리뷰입니다.
#
# 가방 자체는 정말 예쁜데 사은품도 안 왔고 배송이 생각보다 너무 느렸어요 ㅠ
# 91.23% 확률로 긍정 리뷰입니다.
#
# 사진으로 본 것보다 실물이 훨씬 이뻐요 언제든 편하게 매고 다니기 좋을 것 같아요
# 56.99% 확률로 긍정 리뷰입니다.
#
# 우선 사진보다 실물이 훨씬 귀엽구요ㅠㅠ수납공간도 넉넉해서 너무 좋아요
# 60.37% 확률로 부정 리뷰입니다.
#
# 수납공간 엄청 여유롭고 메고 다니기도 편할듯 이쁩니다
# 79.94% 확률로 긍정 리뷰입니다.
#
# 동생 선물로 줬는데 뺏고싶네요안에가 찐주황이라 포인트되고 좋아요공간도 아주 넉넉
# 87.04% 확률로 긍정 리뷰입니다.
#
# 사이즈가 생각보다 크네요재질은 잘 모르겠고 디자인은 너무 맘에 들어요
# 68.20% 확률로 부정 리뷰입니다.
#
# 역시 마크곤잘에스 기대를 져버리지 않습니다 디자인이 너무 이쁘네요
# 56.33% 확률로 긍정 리뷰입니다.
#
# 마크 곤잘레스 진짜 사랑합니다 ㅠㅠ 평소에 마크 곤잘레스 좋아하는데 가방까지 이쁘면 어쩌자는거에요
# 94.09% 확률로 긍정 리뷰입니다.
#
# 복학하면 쓰려구 사게되었는데 생각보다 수납공간이 넉넉해서 심장이 넉다운 될 뻔함 역시 마곤쨩 믿고 있었다구
# 95.84% 확률로 긍정 리뷰입니다.
#
# 너무 이뻐요 안샀음 후회할뻔했어ㅇ요웃음웃음안낡았음 좋겟다 근데 좀 무고운거 넣고다니면 가방끈이 찢어지는듯
# 95.44% 확률로 긍정 리뷰입니다.
#
# 남자친구 선물로 사줬는데 마음에 든데요취향 완전 까다로운데 마크곤잘레스는 좋다고해서 다행ㅜ 가방 예뻐요
# 84.93% 확률로 부정 리뷰입니다.
#
# 흔한 가방들 말고 다른걸 찾다가 발견했는데 맘에 쏙 들어요
# 97.13% 확률로 부정 리뷰입니다.
#
# 디자인이 너무이뻐요 한달을 기다려서 샀었는데 이제야 사용하네요 얼른 학교개학해서 매고다니고싶어여
# 82.88% 확률로 긍정 리뷰입니다.
#
# 가격이 좀 비싸긴한데 그래도 수납공간도 넉넉하고 많이 담아도 어깨가 안불편햐요
# 58.37% 확률로 긍정 리뷰입니다.
#
# 사이즈적당하고 정말 좋네요 학교갈때 맨날 맬듯
# 68.39% 확률로 부정 리뷰입니다.
#
# 저렴한 가격에 너무 잘 산 것 같아요 무게도 가벼운 편이에요
# 63.60% 확률로 부정 리뷰입니다.
#
# 자잘한 수납공간없는게 좀 슬프구 아쉽긴해요 근데 진짜 예뻐요 흔하지도 않고 좋음
# 69.64% 확률로 긍정 리뷰입니다.
#
# 세일할 때 매우 싸게 샀어요 내구성도 완전 좋아서 튼튼합니당 데일리로 잘 들고 다닐수있겠어요
# 90.35% 확률로 긍정 리뷰입니다.
#
# 진짜 수납공간도 많고 크기도 적당해서 매일 쓰기 편한 백팩이에요
# 86.57% 확률로 긍정 리뷰입니다.
#
# 가방이 엄청큰건 아닌데 물건이 많이들어가서너무 좋아요
# 52.67% 확률로 부정 리뷰입니다.
#
# 싸게 사서 그런지 뭐 별다른 감흥은 없네요 싸서 좋아뇨
# 60.27% 확률로 부정 리뷰입니다.
#
# 진짜 안에 주황색 색감 진짜 잘 뽑은거 같아요 학교에 들고다니기 좋을거 같아요
# 91.14% 확률로 긍정 리뷰입니다.
#
# 수납공간도 좋고 무엇보다 끈에 바나나가 조그맣게 있어서 좋다 가방이 흘러내릴때 앞에똑딱이하면 어깨가 덜아프당
# 71.49% 확률로 긍정 리뷰입니다.
#
# 그냥저냥 딱 요즘 학교 주변에ㅓ 많이 보이는 가방정도
# 84.21% 확률로 부정 리뷰입니다.
#
# 가방크기는 생각보다 좀 크고 수납공간은 충분한거같아요 넓고 좋아요 어깨에 그림도 너무귀여움
# 87.70% 확률로 긍정 리뷰입니다.
#
# 빅샷이 너무 많아서 이거샀는데 선배가 가방 바꾸자네요 그정도로 이쁜듯합니다
# 71.40% 확률로 부정 리뷰입니다.
#
# 마크 곤잘레스 마크가 딱 이쁜거 같구 좋아요 잘산거같습니다
# 76.79% 확률로 긍정 리뷰입니다.
#
# 예쁘긴하니요 사이즈도 맞구요 뭔가 안쪽이 잘 더러워질것 같긴한데 색은 예뻐요
# 89.84% 확률로 부정 리뷰입니다.
#
# 튼튼해보이구 괜찮네요 로고가 또렷해서 예뻐여
# 69.10% 확률로 부정 리뷰입니다.
#
# 가방의 디자인도 너무 예쁘고 많이 클까봐걱정했는데 가방을 메보니까생각보다 많이 크지않고 적당해요그리고 수납공간도 적당하구 좋습니다 ㅎㅎ그치만 가방 지퍼가 많이 뻣뻣하고 걸리네요 ㅠ ㅠ이부분이 많이 아쉽지만 좋아요
# 86.97% 확률로 긍정 리뷰입니다.
#
# 흔하지 않은 것 같고 너무 예뻐요 ㅠㅠ 디테일들이 살아있어서 좋아요
# 82.38% 확률로 부정 리뷰입니다.
#
# 일단 가방자체가 이쁘고 편하게 나와서 좋아요그리고 일단 수납공간이 많아서 더 좋고요
# 78.45% 확률로 긍정 리뷰입니다.
#
# 어주누주주주ㅜ주주주주주주주주주주주주ㅜㅈ주ㅜ주주주주주주주죻아요
# 82.79% 확률로 부정 리뷰입니다.
#
# 좋아요 제 기준 크기 적당하고 뭐 넣어도 다 잘들어가고 무엇보다 어깨 끈에 있는 천사가 너무 앙증맞게 함께 다녀줘서 좋아유
# 99.35% 확률로 부정 리뷰입니다.
#
# 예약상품이라 배송될때까지는 오래 기다렸지만 애타게 기다린만큼 너무 만족스러움 ㅜㅜ
# 95.55% 확률로 부정 리뷰입니다.
#
# 가방은 커서 수납공간은 넉넉해서 좋은데 여성이 들기엔 너무 큰감이 있어요 평소 어깨가 아프신분들은 오래 메면 어깨가 좀 아픕니다
# 69.26% 확률로 긍정 리뷰입니다.
#
# 마크 곤잘레스에서 처음 구매해보는데 질도 너무 좋고 가방 크다고 하시는데 저는 인데 딱 맞았어요 너무 예뻐요 사람들도 다 예쁘다고해요ㅠㅠ 다음에 옷도 구매하고싶어요
# 71.66% 확률로 부정 리뷰입니다.
#
# 예약배송 달걸린다고해서 취소할까 하다가 조금 덜 흔한 백팩중에 첨으로 맘에 드는거였어서 한달 꾹참고 기다렸는데 기다린 보람이 있는거같아요 ㅎㅎ 정말 맘에 들고 수납공간이랑 크기도 적당해서 대학생 백팩으로 딱인거 같아요
# 98.59% 확률로 부정 리뷰입니다.
#
# 크기커요 ㅎㅎ 수납공간도 많구요 이것저것 많이들어가서 젛습니다
# 73.73% 확률로 긍정 리뷰입니다.
#
# 가방크기는 무난하고 수납공간도 많아서 좋아요 ㄱ방 밑부분이 경사가있어서 바닥에 놓으면 자꾸 앞으로 엎어져요ㅋㅋㅋ그거빼고는 다 만족스럽습니다
# 71.11% 확률로 부정 리뷰입니다.
#
# 백팩 사고시퍼서 샀는데 크네욤 근데 큰거 좋아해서 ㄱㅊㄱㅊ 잘 메고다닐게요
# 69.34% 확률로 부정 리뷰입니다.
#
# 수납이 좋아요 주머니도 많고 공간도 넓고 노트북도 들어가서 최고
# 84.62% 확률로 긍정 리뷰입니다.
#
# 생각보다 사이즈가 커서 넉넉히 담을 수 있을거같아여 해외여행 갈때 배낭으로 쓰려고 샀는데 만족합니당 ㅎㅎ
# 92.35% 확률로 긍정 리뷰입니다.
#
# 시기에 잘 맞게 싸게 잘 산것 같아서 만족스럽고 이쁩니다
# 82.29% 확률로 긍정 리뷰입니다.
#
# 가방은 큰 편이이어서 수납도 넉넉합니다가방도 가볍고 안에는 오렌지색이어서 더 맘에 들어요
# 75.96% 확률로 부정 리뷰입니다.
#
# 안쪽에 오렌지색이 포인트 되서 예쁘네요 학생들 가방으로 좋을 거 같아요
# 93.21% 확률로 긍정 리뷰입니다.
#
# 가방 디자인만 보고 샀는데 자잘자잘한 수납공간이 부족해서 살짝 아쉬웠어요 그 외에는 정말 마음에 듭니다
# 59.85% 확률로 부정 리뷰입니다.
#
# 길 가다 같은 가방 본 적도 없고 물건도 잘 들어가고 좋아요
# 94.93% 확률로 부정 리뷰입니다.
#
# 제 몸에 딱맞고 편하네요  세일할때 샀는데 아주 좋습니다
# 95.81% 확률로 부정 리뷰입니다.
#
# 가방만원대에 싸게 잘삿어요 이쁩니다 잘매고다녀요
# 68.73% 확률로 부정 리뷰입니다.
#
# 가방 내부도 용량도 정말크고 내부에 주황색정말이쁘고 꼭사세요
# 70.82% 확률로 긍정 리뷰입니다.
#
# 갔을때 썼는데 그냥 돌아다닐때 써도 좋았고돌아오는날에 막 쑤셔넣었는데 군데로 나눠져있어서 대부분 다 들어갔어요생각보다 많이 들어가서 좋았어요
# 83.07% 확률로 긍정 리뷰입니다.
#
# 아주 이쁨 약간 자크가 빡빡하긴 함 수납공간이 중간이없음 다 큼
# 92.40% 확률로 긍정 리뷰입니다.
#
# 수납이 적당히 많이 있고 깔끔해서 데일리로 딱입니다 만족스러워요 예쁩니당
# 75.48% 확률로 부정 리뷰입니다.
#
# 딱 실물깡패라는 말이 맞는듯요 개강때 매도 이쁠거같아요
# 56.44% 확률로 부정 리뷰입니다.
#
# 일단 가벼워요 전에 쓰던 잔스포츠 가방보다 수납력은 모자르지만 가방 아래쪽에 받침대가 있어서 모양도 쳐지지 않고 앞쪽에 스트랩도 좋아용
# 98.01% 확률로 부정 리뷰입니다.
#
# 크기도 적당하고 무난하게 매고 다니기 좋아여지퍼가 조금 아쉬울 뿐
# 66.32% 확률로 부정 리뷰입니다.
#
# 생각보다 가방 디자인이 이쁘고 안에 주황색으로 되어있어서 가방안은 색다른 느낌에 들어요
# 84.81% 확률로 긍정 리뷰입니다.
#
# 공부하려고샀는데 수납공간이 낙낙히 들어가고 생각보다 좀 커요 그리고 핏이 예쁘게 떨어져서 평소에도 잘매고 다녀요 안에 색이 달라서 포인트도 되는ㅅ것같아요
# 97.97% 확률로 부정 리뷰입니다.
#
# 마크 곤잘레스는 항상 만족해요 가방 너무 예쁩니당
# 57.67% 확률로 긍정 리뷰입니다.
#
# 가방안에 색감이 너무 쨍해서 보기좋아요 예쁘네요 만족합니다
# 85.51% 확률로 부정 리뷰입니다.
#
# 완전 제가 원하는 스타일에 가성비 갑인 거 같아요
# 97.21% 확률로 부정 리뷰입니다.
#
# 아직은 흔하지 않은편이라 좋네요 잘들고다닐게요
# 51.76% 확률로 부정 리뷰입니다.
#
# 엄청 고민하다가 샀는데 크긴 하지만 생각보다 괜찮은거같아요 넘넘넘넘 이뻐요 진짜ㅜㅜ
# 87.86% 확률로 긍정 리뷰입니다.
#
# 평소 마곤브랜드 진짜 좋아하는데가방역시 좋네요열었을때 안쪽 쨍한 주황색감이 너무 맘에들어요
# 84.49% 확률로 긍정 리뷰입니다.
#
# 여자친구 선물로줬는데 좋아하네여 학교다닐때 쓰기 좋은것같아요
# 98.69% 확률로 부정 리뷰입니다.
#
# 가방도 가볍고 수납공간도 적당해서 좋은 것 같아요
# 80.08% 확률로 긍정 리뷰입니다.
#
# 로고가 커서 너무 예쁘고 스카치라 더 예쁩니다 두번 사세요
# 86.88% 확률로 부정 리뷰입니다.
#
# 정말 정말 이쁘고 등에 착 붙어서 편안하게 사용할 수 있어요ㄹㅇ 강추
# 79.72% 확률로 부정 리뷰입니다.
#
# 가방크기 큰 게 갖고 싶어서 찾다가 찾다가 이거 샀는데 딱 원하는 크기에욤 왕 크니까 왕 귀엽다 앞에 스카치도 반짝반짝 예뻐요 가슴줄이 좀 얇아서 아쉬운데 그거 말구 다 너무 예뻐요 히히
# 94.97% 확률로 부정 리뷰입니다.
#
# 키가 작아서 등짝전체를 얘가 커버해요 친구들이 거북이 등딱지냐고 놀려요 왜이렇게 바짝메고 있냐해요 그래도 가방 예쁘게 잘 샀어요 단으로 나눠져 있는지 몰랐지만 잘 쓰는 중
# 81.38% 확률로 부정 리뷰입니다.
#
# 정말정말 좋아요 만족스러운데 가방끈이 너무 약해서 조금 뜯어졌네요 ㅜㅜ
# 65.04% 확률로 부정 리뷰입니다.
#
# 좋아요 크기도 크고 안에 색깔도 평범하지 않은게 좋습니다 원래 마크 곤잘레스 제품을 좋아했던 터라 바깥 프린팅도 좋네요
# 99.06% 확률로 부정 리뷰입니다.
#
# 백팩 앞쪽에 써있는 마크 곤잘레스도 반사되는 듯한 느낌이라 좋구 무엇보다 가방 수납공간이 많은 건 아닌데 넓어요 옆에 있는 매쉬소재 포켓 빼면 작은 수납공간이 안쪽에 하나밖에 없다는게 좀 아쉽지만 그래도 넓고 가벼워서 저는 만족합니다 같이 온 달력도 너무 귀여워요
# 50.50% 확률로 부정 리뷰입니다.
#
# 요즘 커버낫 가방이 눈에 많이 띄길래 좀 색다른걸 원해서 샀습니다 역시 이뻐요
# 89.60% 확률로 부정 리뷰입니다.
#
# 전체적으로 마음에 쏙 드네요 구입하길 잘 한것 같아요잘 매고 다닐게요
# 99.79% 확률로 부정 리뷰입니다.
#
# 편하게 쓸 가방 필요해서 세일할 때 샀는데 가성비 좋아요
# 80.01% 확률로 긍정 리뷰입니다.
#
# 일단 디자인이 예쁘구요 가방 속의 수납공간이 조금만 더 있으몈 좋겠습니다
# 65.90% 확률로 부정 리뷰입니다.
#
# 마크 곤잘레스 답습니다 믿고 사세요 사은품으로 준 달력과 스티커도 너무 예쁘네요 ㅎㅎ 잘쓰겠습니다
# 80.30% 확률로 긍정 리뷰입니다.
#
# 데일리로매기좋은거 같아요 사이즈도적당하고이쁩니다
# 87.87% 확률로 부정 리뷰입니다.
#
# 수납공간이 생각보다 엄청 넓어서 책 여러권 넣기도 편하고 흔하지 않은거같아서 너무 좋고 이뻐요
# 60.32% 확률로 긍정 리뷰입니다.
#
# 예쁜데 제 키에는 커요ㅠㅠ 그래도 잘 들고 다닙니당 만족해용
# 97.46% 확률로 부정 리뷰입니다.
#
# 그냥 이거 들어가자마자 뜨길래 샀는데 괜찮은것같음
# 73.09% 확률로 긍정 리뷰입니다.
#
# 생각보단 좀 작은데 그래도 이쁘기 때문에 모든게 용서가됩니다
# 85.12% 확률로 긍정 리뷰입니다.
#
# 상품 상세정보보다가 주황색 내피보고 바로 질렀어요생각보다 수납공간이 많지는 않지만 이것 저것 넣어다닐거 아니어서이정도면 만족합니다 너무 예쁘고 마음에 들어요
# 92.86% 확률로 긍정 리뷰입니다.
#
# 인터넷에 후기가 많이 없어서구매하고나서 취소하고 다른 가방으로 사야하나 고민했었는 데 그럴 필요가 전혀 없었네요유니크하고 예뻐요예쁜 가방 보내주셔서 정말 감사합니다
# 98.77% 확률로 부정 리뷰입니다.
#
# 만족스럽습니다 크기도 수납공간도가격대비 만족도 좋아요
# 69.36% 확률로 긍정 리뷰입니다.
#
# 일단 가방이 가볍고 편하네요크기도 적당하고 디자인도 예뻐서 아주 만족합니다ㅎㅎ
# 63.34% 확률로 긍정 리뷰입니다.
#
# 진짜 너무 예쁘고 후회 없습니다ㅠㅠ수납공간도 엄청 넉넉하고 뭐를 입던지 다 어울리는것같아요
# 85.74% 확률로 긍정 리뷰입니다.
#
# 그냥 생각했던 대로네요 아주 좋습니다 님덜 빨리 사십시오
# 84.84% 확률로 긍정 리뷰입니다.
#
# 처음 뜯었을 때 냄새가 좀 났지만 한 삼일 밖에 두면 빠지겠죠 뭐 수납공간 넉넉하고 안쪽이 주황색인게 좀 띠용이긴해도 포인트라고 생각하면 과하지않은 수준 근데 마크곤잘레스 글씨부분이 번쩍거려서 좀 부담스럽네요 ㅋㅋㅋ 하얀색인줄알았는데 거의 은색입니다 그래도 가방이 크니까 여기저기 매고다녀도 좋겠어요 박정도 여행갈때 딱일듯
# 95.52% 확률로 긍정 리뷰입니다.
#
# 인케이스 가방 사용 중인데 무신사에서 가방 새로 사봤습니다 ㅎㅎ수납 공간 넉넉하고 일단 디자인 이쁘고 제가  인치짜리 띵패 사용중인데 노트북 수납 공간에 딱 맞게 들어가요
# 86.68% 확률로 긍정 리뷰입니다.
#
# 살까말까 고민하다가 재고개 남은거보고 바로 구매했는데 진짜 이뻐요ㅜ 특히 앞에 마크곤잘레스라고 적혀있는게 포인트가되니깐 이뻐요잘 매고 댕길것같습니다
# 94.43% 확률로 긍정 리뷰입니다.
#
# 디자인도 예쁜데 생각보다 커서 좀 거북이 등딱지 같아요
# 64.83% 확률로 긍정 리뷰입니다.
#
# 가방 내부 색깔은 호불호가 갈릴 수 있다디자인은 굉장히 마음에 들고 다용도로 홞용 가능할 듯 하다
# 50.81% 확률로 부정 리뷰입니다.
#
# 힙하다힙해 세상힙해 아 가방 자체가 너무 예뻐서 그냥 고민도없이 바로 구매한것같아요 기대했던것만큼 너무 예쁘고 은근 수납공간이 나뉘어져 있어서 편리하고 좋을것같습니다
# 84.25% 확률로 긍정 리뷰입니다.
#
# 마음에 드는 백팩 찾고있었는데딱입니다 세일때 사서 기분좋아여
# 99.34% 확률로 부정 리뷰입니다.
#
# 요즘 커버낫 칼하트 가방 많이 써서 다른 브랜드 찾다가 마크곤달레스  가방도 크고 디자인도이쁘고 너무 좋네요
# 91.03% 확률로 부정 리뷰입니다.
#
# 가방을 메면 등이 되게 편하고 좋아요감사합니다
# 83.97% 확률로 부정 리뷰입니다.
#
# 커요 조금 적당히 크면 될거같은데 생각했던거 보다 배 더 큰거 같아요 근데 너무 예뻐요
# 84.68% 확률로 긍정 리뷰입니다.
#
# 진짜 이쁜거 같아여ㅜㅜㅜ키 이라서 조금 크긴한데 수납공간도 많고 다 좋네요
# 95.80% 확률로 긍정 리뷰입니다.
#
# 무난하게 메고 다니기 개안아요스타인 이쁩니다
# 84.44% 확률로 부정 리뷰입니다.
#
# 진쨔류 이쁘네요 디자인이 괜찮고 무게감도 좋구 딱 좋아요
# 59.03% 확률로 부정 리뷰입니다.
#
# 디자인도 너무 예쁘고 블랙도 깔끔해서 좋아요 좀 큰 가방을 원했는데 너무 크지 않고 적당히 커서 더 예뻤어요 가볍고 어떤 옷에도 다 잘 어울려서 만족합니다
# 68.78% 확률로 긍정 리뷰입니다.
#
# 가방이 생각보다 조금 커서 놀랐는데 커서 더 예쁜 것 같아용
# 60.94% 확률로 긍정 리뷰입니다.
#
# 세일할때 사서 가격도 괜찮고 안에 색도 이뻐요 굿
# 77.83% 확률로 긍정 리뷰입니다.
#
# 흔한거 싫어서 며칠동안 고민했는데 발견하게 되어서 너무 좋았어요안 흔해지면 좋겠어요ㅠㅜㅠㅜㅜㅠ 그만큼 예뻐요
# 84.49% 확률로 부정 리뷰입니다.
#
# 근데너무 예뻐요ㅠㅠㅠㅠ 수납공간은 많은편은 아니지만 커서 잘들고 다녀용
# 92.89% 확률로 긍정 리뷰입니다.
#
# 수납공간 정말 많고 가방이 튼튼해서 좋아요 추천합니다
# 72.83% 확률로 긍정 리뷰입니다.
#
# 마침 이 가방이 세일하길래 샀는데 수납공간도 괜찮고 노트북 넣는 곳도 있어서 편하고 좋아요
# 90.96% 확률로 긍정 리뷰입니다.
#
# 사진으로도 이쁜데 실제로 보니 더 이쁘네요 만족합니다
# 63.77% 확률로 긍정 리뷰입니다.
#
# 제가 생각했던 데일리에 매기좋고 이쁜 가방이에요
# 97.81% 확률로 부정 리뷰입니다.
#
# 여성분들이 매시기에도 절대 크지 않고 딱 등에 맞는 사이즈에요 사진 보다 실물이 훨씬 예쁘고 로고가 좀 커서 너무 튀지 않을까 걱정 했는데 오히려 적당히 눈에 띄고 아주 예뻐요 다른 가방이랑 고민했는데 이게 세일하길래 샀는데 잘 한 것 같아요
# 69.11% 확률로 긍정 리뷰입니다.
#
# 진짜 너어어어어어어어어어어어어어어어어무 마음에 들어요
# 69.36% 확률로 긍정 리뷰입니다.
#
# 개인작으로 마크곤잘래스를 좋아해서 가방도 사봣는데 크기 디자인 가방끈에 바나나새까지 너무 맘에듭니다 ㅎ
# 92.12% 확률로 긍정 리뷰입니다.
#
# 나 사고나니까 품절돼서 진짜 기뻤어요 사람들 보는 눈 있다니까요 ㅠㅠ 여태 샀던 가방 중에서 젤 사랑스러운 가방
# 96.91% 확률로 긍정 리뷰입니다.
#
# 백팩이 필요했는데 수납공간도 엄청 많고 별로 무겁지 않아서 좋고 뒤에 글자보고 산건데 넘 이뻐여 그리고 배송이 빨라서 너무 좋네요 곤잘레스 굿굿
# 91.19% 확률로 긍정 리뷰입니다.
#
# 학교 가방으로 잘 쓰고 있어요 노트북 수납도 되고 다른 수납 공간도 많아서 좋아요 다른 백팩이라는 다르게 동그랗고 납작하게 모양이 잡혀있어서 쳐지거나 그런 느낌은 없는 것 같아요귀엽싑니다
# 66.22% 확률로 긍정 리뷰입니다.
#
# 선물받은 사람이 만족해하고 주는 저도 엄청 이쁘다 생각했어요로고가 세로로 들어가있는게 되게 예뻤어요
# 64.91% 확률로 부정 리뷰입니다.
#
# 메고 다니던 가방이 수명을 다 해서 이것저것 알아보다가 얘한테 꽂혀서 샀는데 이뻐요 ㅠ 진짜 튼튼하고 수납공간도 정말 넉넉하니 좋습니다 잘산 것 같아요 전공 책이 진짜 무겁고 크기도 큰데 그런거 여러권 넣어도 안쳐지더라구요ㅋㅋㅋㅋㅋㅋ 좋아용
# 93.98% 확률로 긍정 리뷰입니다.
#
# 이제 곧 복학하는데 이 가방 매고 댕기면 그냥 인싸 확정이요 원래 가방을 안좋아했는데 요거 사고 나서부터는 그냥 맨날맨날 짐없어도 그냥 매고 댕기네요
# 98.48% 확률로 부정 리뷰입니다.
#
# 수납공간도 많고 크기도 커서 이것저것 넣고 다녀요그런데 가방 자체 무게가 무거워서 별 하나 뺍니다
# 56.47% 확률로 긍정 리뷰입니다.
#
# 사진보다 이쁩니다 가방 구우우웃입니다ㅎㅎ 사지말아주세ㅛㅇ
# 67.52% 확률로 긍정 리뷰입니다.
#
# 가방 이쁘네요 역시 마크곤잘레스 기대이상입니다
# 54.36% 확률로 긍정 리뷰입니다.
#
# 가방 커서 좋구요거의 한달 째 메고 있는데 디자인 예뻐요 ㅜㅜ 안질림원래 가방에 쑤셔넣는 편이라 수납공간 신경안써서 잘 모르겠긴한데 이정도면 충분한 것 같아요가방이 단이라고 해야되나 맨 앞에 수납공간 가운데 수납공간 있고 맨 뒤에가 그 제일 넓어서 책넣은곳 그렇게 되있고노트북 넣는곳도 단단히 되어있어서 좋고다른거 다필요없고 어차피 수납공간은 옆에달린 주머더보기
# 80.26% 확률로 긍정 리뷰입니다.
#
# 수납공간 큰것만 개나 되고 가방 착용했을때 불편한거 없음 디자인이 마음에든다면 사도 좋을제품
# 62.67% 확률로 긍정 리뷰입니다.
#
# 배송도좋고수납공간도널널해최애템이당앞으로도 땀것도 사야지
# 73.68% 확률로 긍정 리뷰입니다.
#
# 가방 내부가 형광 주황색이라서 톡톡튀어서 이쁘고 가방 줄에 있는 새 로고 너무 귀여워요 무난하게 잘 매고 다닐거 같아요
# 98.72% 확률로 부정 리뷰입니다.
#
# 고민하다가 샀는데 매우 만족합니다 다들 고민말거 사세요 굳입니다
# 83.89% 확률로 긍정 리뷰입니다.
#
# 완전 강추합니다 생각보다 수납공간 많고 디자인도 너무 이쁘게 빠져서 저렴하게 아주 이쁜 가방 득템해서 너무 조아요
# 60.61% 확률로 긍정 리뷰입니다.
#
# 사진보다 가방도 크고 예쁘네요 수납도 적당한거같아요 그런데 그렇게 막 수납이 좋은편은 아니에요
# 70.74% 확률로 긍정 리뷰입니다.
#
# 지퍼가 조금 퍽퍽한데 그 것 말고 수납공간도 넉넉하고 예쁘기도 진짜 예뻐서 만족합니다
# 92.75% 확률로 긍정 리뷰입니다.
#
# 이런 디자인의 가방들 찾기 쉬운데 타 가방들에 비해서 크고 안에 주황색이 이 가방의 반전 매력임 예쁘고 허리에도 착 감겨서 마음에 듦
# 55.37% 확률로 부정 리뷰입니다.
#
# 동생 선물로 샀는데 만족도가 매우 높네요ㅎㅎ가방 이쁘다고 난리에요
# 97.53% 확률로 부정 리뷰입니다.
#
# 마크곤잘레스 너무좋어요 가방 너무이뻐요 싸랑해요
# 77.11% 확률로 부정 리뷰입니다.
#
# 마크 곤잘레스 가방 너무 이쁘고 수납공간도 많고 좋아요
# 83.80% 확률로 긍정 리뷰입니다.
#
# 색상도 사진이랑 똑같고 다 만족스러워요 가성비 좋네요
# 57.45% 확률로 부정 리뷰입니다.
#
# 진짜 생각한거 이상으로 매우만족하고 사용중이에요 진짜 맘애들어용
# 94.31% 확률로 긍정 리뷰입니다.
#
# 데일리 가방이 필요해서 구입 마음먹은 후 다른 친구들 가방 유심히 살펴서 따라 산 가방입니다 겉모습 뿐만아니라 수납 공간도 만족스러운 가격과 제품입니다
# 91.19% 확률로 부정 리뷰입니다.
#
# 고민을 많이하다가 고른거였는데 실물로 보니 가방 사이즈도 넉넉하구 딱 좋아요
# 51.23% 확률로 긍정 리뷰입니다.
#
# 생각보다 크고 이뻐서 좋아요 안에는 주황색으로 되어 있어서 물건들이 잘 보여서 좋아요
# 81.10% 확률로 긍정 리뷰입니다.
#
# 덩치가 커서 고민이었으나 문제없이 소화가능합니다
# 89.23% 확률로 긍정 리뷰입니다.
#
# 원더플레이스에서 보고 반해서 여기서 구매했는데 정말 너무 맘에듭니다
# 99.45% 확률로 부정 리뷰입니다.
#
# 요즘 가방 칭찬 엄청 듣고다닙니다 예쁘고 수납도 좋아여한가지 아쉬운건 노트북 포켓이 인치 한성을 버거워한다는거ㅠㅜ꾸겨넣고 다녀요
# 55.12% 확률로 부정 리뷰입니다.
#
# 가방 이뻐요 평상시에 메고 다니기도 좋고 만족합니당
# 95.58% 확률로 부정 리뷰입니다.
#
# 마크 곤잘레스 가방 사봣는데 무지무지 이뻐요아쉬운건 가방바닥부분에 평평하게 받쳐주는거 그게 없어서 아쉽지만 물건 넣고 뭐하면 좋을듯합니다잘쓸게요
# 71.22% 확률로 긍정 리뷰입니다.
#
# 보이는것 처럼 똑같고 마감도 좋고 로고가 빛에 반사되는 재질이네요 대만족합니다
# 84.09% 확률로 부정 리뷰입니다.
#
# 저는 수납공간이 생각보다 적을줄알았는데 수납공간 많네요 그리고 두번째칸에 파우치도있어서 좋네요 여성분들 참고하시길
# 76.79% 확률로 긍정 리뷰입니다.
#
# 수납공간이 엄청 널널해서 좋음 가방고리랑 가방끈이 꿀귀
# 73.78% 확률로 긍정 리뷰입니다.
#
# 크기가 많이 크더라구여 앉아있을때 가방 안고있으면 너무 편해여
# 59.81% 확률로 부정 리뷰입니다.
#
# 백팩 증맬 오랜만에 샀는데 잘산거같아요 편하고 예쁩니다
# 60.38% 확률로 부정 리뷰입니다.
#
# 여자 친구가 정도 되는데 허리끝선까지 와요 길이가 긴거 같아요 가방은 잘 빠졌어요
# 90.50% 확률로 부정 리뷰입니다.
#
# 여자친구가 샀는데 완전 만족해해여 가방 이쁘고 귀여워요 굿굿
# 97.35% 확률로 부정 리뷰입니다.
#
# 사진보다 실물이 훨씬더 이쁘고 깔끔해요가격도 디자인 비슷한제품에 비해서 저렴하니 정말 좋습니다
# 56.71% 확률로 긍정 리뷰입니다.
#
# 크기가 많이 크진 않을까 고민했는데 디자인도 깔끔하고 크기도 인 저한테 안크고 너무 예뻐요
# 84.50% 확률로 부정 리뷰입니다.
#
# 근데 지퍼 부분이 좀 뿌억뿌억해요 ㅠㅜ그래도 이쁘니 만족합니다
# 53.07% 확률로 부정 리뷰입니다.
#
# 좋은데 얼마안매고 어깨끈이 튿어진게 아쉬워요 ㅠㅠ근데 아직 디자인이 안흔해서 좋아용
# 94.64% 확률로 부정 리뷰입니다.
#
# 키 이하 이신 분들한테는 좀 많이 클거같아요 그래도 가방은 너무 예뻐요 디테일들도 맘에 들어요
# 98.35% 확률로 부정 리뷰입니다.
#
# 키 이고 어깨가 여자 치곤 꽤 넓은데도 가방이 컸습니다 그래도 오히려 이런 널널한 폼이 좋아서 만족하고 매는 중입니다  기격도 무난하고 수납공간 많아서 좋구 흔하지도 않아서 좋아요
# 65.43% 확률로 부정 리뷰입니다.
#
# 사진보다 실물이 훨씬 예뻐요 ㅠㅠ딱 원하던 스타일 커버낫중에 고민하다가 결국 맠곤 질렀는데 만족만족
# 75.26% 확률로 부정 리뷰입니다.
#
# 인데 길이도 딱 괜찮고 글씨가 넘 예쁘네요추천합니다
# 79.69% 확률로 긍정 리뷰입니다.
#
# 맠곤 역시나 예쁩니다인데 등짝 다 덮구요여러가방을 지났지만 정착합니다 굿
# 99.47% 확률로 부정 리뷰입니다.
#
# 그래서 수납이 쌉오져요또 안에 형광오랜지색상도 맘에들구요 공간이 개라 분할해서 넣어놓기도 좋구요 생긴것도 엥간이에요
# 92.61% 확률로 부정 리뷰입니다.
#
# 배송빠르고 실물깡패에요 키인 저에겐 좀 크긴하지만 맬때 편하고 좋네요
# 95.93% 확률로 부정 리뷰입니다.
#
# 근데 예뻐요 키가 인데 엉덩이까지 오구 등짝을 다 덮어요 귀엽고 수납 공간 많아서 좋습니당
# 83.87% 확률로 부정 리뷰입니다.
#
# 진짜러 수납공간크고 예쁘고 너무 잘산거같다는생각듭ㅂ니다
# 95.55% 확률로 긍정 리뷰입니다.
#
# 좋아요커서 많이 들어가고 개로 나누어져 있어서 편하고 예뻐요
# 73.48% 확률로 부정 리뷰입니다.
#
# 다른 브랜드 가방이랑 고민하다가 할머니도 이게 더 예쁘다고 하셔서 바로 이거로 구매했는데 정말 후회하지 않아요ㅜ 사실 마크곤잘레스 다른 제품을 처음에 고민했는데 그건 사이즈가 작을거같아서 안했는데 이건 사이즈가 정말 제가 찾는 최고의 사이즈입니다 ㅜㅜ
# 69.89% 확률로 부정 리뷰입니다.
#
# 진짜 너무 예쁘고 무엇보다 튼튼한게 느껴지고 수납공간이 착착 있는건 아니지만 잘 나누어져 있어요 약간 별로인건 인데 어깨길이 다 줄여도 걸을때 엉덩이 탁탁 치는게 쫌 있어서 거슬리는거 남자분 등에 더 알맞을거 같아요 매우큼
# 79.42% 확률로 긍정 리뷰입니다.

# %%
# positive_data 를 한 배열에 모두 넣고 명사로 분리
text3
text4 = []
text5 = []
bl=[]
for i in range (len(positive_data)):
    text3 = ' '.join(positive_data[i])
    text4.append(text3)
text5 = ' '.join(text4)

print(text5)
# Out:
# 마크곤잘레스 사랑 엔젤 키 링 생각 절 때 엔젤 키 링 느낌 앞 이 백 팩 예정 방 고민 마크곤잘레스 추천 가방 크기 언제 것 수납 공간 학교 책가방 디자인 추천 학생 가방 가방 편 것 때 불편 건 천 사 일 명 바나나 인형 포인트 생각 거 추천 마감 안 진짜 성비 디자인 구성 가격 실물 만족 수납 공간 스타일 활용 수 수납 공간 친구 가방 생각 만족 제품 수납 공간 과 성비 가방 디자인 포인트 바나나 누가 가방 등 것 노트북 인치 걱정 쥬얼 거 마법 유쾌 쾌 중 남아 요요 고요 학년 때 가방 달 거북 등딱지 느낌 가방 수납 공간 달기 짜증 맘 울딸 완전 마음 등산 가방 스타일 처음 앞 주머니 수납 공간 게 단점 것 안정 완전 만족 노트북 인치 가방 이상 가방 등 부분 판 위 쿠션 등 가방 가방 수납 공간 디자인 교복 매도 대 거 인형 키 걱정 크기 만족 여성 거 디자인 걱정 가방 데 만큼 인형 최고 포인트 책 일다 수납 공간 편리 디자인 옷 때 구매 만족 수납 공간 인형 포인트 여러분 마크 곤잘레스 수납 공간 여 인형 가방 디자인 인형 가방 최고 패션 아이템 아기 자기 가방 수 여 학생 여행 레저 적극 추천 남자 생각 생각 용 구매 하세오 완존 귀여 웅 가방 수납 공간 인형 맘 옷 수납 공간 편 무엇 엔젤 마음 키 센티 지퍼 스트링 지퍼 엔젤 키 링 가방 수납 공간 최고 사이즈 수납 공간 마크곤잘레스 인형 티머니 카드 디자인 수납 공간 칸 바나나 줄 천사 인형 거 노랑 색 인트 거 글씨체 바나나 포인트 바나나 인형 앞 배송 것 갗 수납 공간 낭 낭 인형 카드 생각 것 거 강추 바나나 맘 거 불편 가방 수납 공간 여 디자인 여 실용 송 가방 가방 밑부분 받침 데 쿠션 처리 것 수납 칸 칸 쉬망 오거 나이저 중간 칸 거 개 수납 전체 만족 걸 원 생각 게 여행 것 키 링 마음 사은품 마음 전체 조화 유행 느낌 내구 앞 기대 가방 용 가방 공간 옷 보따리장수 왕 가방 로고 생각 수납 공간 스티커 노트북 로고 빛 반사 것 생각 용량 가방 용량 마음 디자인 디자인 실물 바나나 인형 무엇 가격 성비 가방 수납 공간 거 학기 교과서 정도 처짐 거 여 수납 공간 인형 전체 거 마크 곤잘레스 노랭이 성비 거 여자 친구 말 가방 디자인 평소 것 수납 공간 노란색 인형 가방 어디 옷 동생 입학 선물 구매 공간 바나나 만큼 가방 삿 수납 공간 즉시 기분 수납 부분 번 칸 게 거 키 인형 기여 워 중학생 아들 가방 수납 맘 여행 가방 꺼 합리 가격 상품 구매 감사 캐주얼 공간 분할 등 만큼 팟 상하 느낌 안 포인트 색 생각 것 수납 공간 만족 무게 만족 디자인 말 것 용 수납 공간 안정 커버 낫 이거 고민 삿 후회 조아 제 가방 중 가방 공간 활용 오렌지 색깔 선명 수납 공간 데 가방 메기 편안 남자 친구 선물 최고 키 크기 등 수납 넉 넉 노트북 밑바닥 사선 바닥 때 커버 낫 제 생각 데일리 룩 가방 기대 거 맘 여 지퍼 뿐 고민 생각 만족도 사이즈 커버 낫 마크곤잘레스 후회 품절 거 수납 공간 안 오렌지 색 것 포인트 것 욥 데일리 가방 사용 상황 자연 스타일 로고 가방 앞 전체 염려 검정 가방 만족 요키 등짝 다가리 가방 블랙 주황 게 반전 매력 가방 것 백 팩 크기 가격 디자인 맘 후기 고민 분 거 데 거 힙 노트북 것 무게 가방 옷 지퍼 부분 마감 금상첨화 뎁 어깨끈 캐릭터 옆 친구 너 가방 저 것 자기 사 세 오 배 사이즈 노란색 인형 포인트 용 제 마음 최애 가방 맥북 그거 어깨 쪽 학교 때 부모 가방 책 이건 매일 규 수선 것 인형 포인트 가방 것 인형 수납 공간 맘 가방 추천 바나나 편리 배송 완전 만족 마크 래스 마크 인형 공간 수납 공간 포켓 게 개 꺼 배송 완전 만족 공간 생각 수납 공간 학교 책가방 디자인 추천 마크곤잘레스 개인 마크곤잘레스 로고 디자인 마음 사이드포켓 지퍼 부분 디테일 굳 생각 수납 공간 게 가운데 앞 수납 공간 물건 공간 것 가방 디자인 마크곤잘레스 인형 만족 수납 공간 게 장점 것 가방 기본 무게 마음 거 추천 수납 곳 천사 포인트 우리 애 명다 제품 구입 바나나 갈매기 인형 수납 공간 만족 가방 크기 디자인 인형 마음 지퍼 것 단점 생각 것 이상 수납 공간 마크곤잘레스 디자인 가방 디자인 수납 공간 사이즈 인형 나무 마크곤잘레스 가방 마크 곤잘레스 디자인 심플 엣지 수납 공간 거 마크 곤잘레스 백 팩 인형 사은품 감사 수납 공간 물건 기준 엉덩이 디자인 마음 책 가방 수납 공간 인형 줄 데 수납 공간 키 링 생각 바나나 비둘기 수납 공간 디자인 키 링 만족 수납 공간 길 조절 배송 엔젤 가방 크기 맘 노트북 인치 걱정 커버 낫 마크 곤잘레스 가방 구매 생각 모양 재질 때 친구 박일 여행 때 것  가방 수납 크기 부담 어깨 부분 어깨 내기 느낌 디자인 수납 공간 가방 것 매장 착용 구매 거 만족 바나나 인형 뻔 완벽 만족 가방 가방 마스코트 때문 구매 은근 실용 모양 디자인 배송 생각 디자인 인형 가방 월 발송 선물 느낌 마크곤잘레스 로고 은색 수납 공간 디자인 키 링 마음 단점 처음 세 고등 아들 가방 무엇 성비 갑 디자인 가방 높이 편 불편 수납 등판 쿠션 모양 고등 학생 대학생 등산 때 무엇 엔젤 가방 마크 자르 레스 학기 수납 공간 것 것 키 링 맘 가방 바나나 취 용 학교 때 노트북 공책 아이패드 가방 용서 사진 동일 착용감 수납 공간 키 가방 걱정 교복 때 수납 공간 가지 단점 앞쪽 등판 쪽 쿠션 가방 쪽 생각 가방 수납 공간 거 맘 인형 아이패드 고민 열 개 듯 무게 추천 유행 디자인 마곤 가방 수납 공간 앞 키 링 수납 공간 가방 수납 공간 유용 만족 가방 인형 맘 방안 밴드 인치 노트북 그것 수납 공간 마크 곤잘레스 로고 인형 수납 공간 편리 디자인 옷 마음 인형 가방 것 사이즈 맘 핏 마음 수납 공간 인형 고등학교 가방 하나 장 느낌 느낌 지퍼 구 디자인 수납 공간 만족 용량 생각 템 듯 사이즈 수납 공간 블랙 색감 선명 트레이드 마크 가방 퀄리티 키 남학생 굿 고아 신학기 선물 구매 수납 공간 디자인 맘 중학생 아들 탐 사이즈 실물 바나나 우리 집 강아지 탐 꺼 제 꺼 수납 공간 노란색 인형 고등 학생 구입 추천 게 책가방 수납 공간 인형 맘 배송 만족 처음 곳 지퍼 때 감 사용 수납 공간 번 사진 것 마감 상태 맘 백 팩 수납 공간 키 포인트 맘 크기 수납 공간 지퍼 스트링 지퍼 가방 수납 공간 가방 자체 인형 귀여 웡 사이즈 무게 만족 학교 때 사용 거 수납 공간 가방 사이즈 만족 배송 마크 곤잘레스 사은품 인형 가방 생각 거 완 죤 사이즈 학기 가방 학교 수 지퍼 열 때 불편 점 굿 가방 기대 것 키 조심 생각 크기 가방 것 가방 중 딸아이 맘 대요 수납 년 동안 중학교 때 책가방 사용 것 바나나 인형 앞 나 생각 기엽 수납 공간 옷 것 가방 디자인 가방 부분 것 가방 수납 공간 여 디자인 가방 크기 것 메 쉬망 수납 부족 전체 만족 까탈 우리 엄마 심사 가방 칭찬 지퍼 ㄷ 무시 만족 합 가방 공간 옷 로고 수납 공간 실용 대학생 ㄷ 노트북 공책 마곤 가방 가방 필요 만족 가방 마곤 인형 카드 가방 수납 꺼 것 인형 생각 인형 봄 이거 저 키 거북 등딱지 줄 생각 조아 크기 데 건 사실 키 사은품 티머니 수납 공간 사은품 만족 지퍼 불편 거 디자인 수납 공간 생각 것 듯 중학교 아들 녀석 가방 디자인 수납 수납 공간 무게 것 가방 노트북 수납 데 노트북 책 권 바나나 인형 가방 받침대 안 책 것 디자인 이번 고등학교 엄마 나이키 가방 지퍼 거 수납 공간 사실 키 행보 티머니 카드 타일 바 용량 디자인 가방 실물 바나나 인형 포인트 듯 수납 공간 생각 수납 공간 바나나 인형 포인트 인형 스티커 수납 공간 가방 생각 거 거 수납 인형 초등 학교 졸업 학교 기본 가방 키 링 바나나 사이즈 것 아들 램 신학기 가방 사이즈 수납 공간 디자인 아이 만족 사이즈 맘 삿 디자인 가방 퀄리티 기대 가방 맘 앞 쉬망 거 고민 이거 듯 수납 공간 디자인 수납 공간 인형 전체 대학교 입학 인치 노트북 외 수납 공간 배송 디자인 기대 거 키 링 가방 거 바나나 포인트 옆 엔젤 ㅣ 만족 칸 활용 거 노랭이 성비 거 가방 색감 디자인 마음 무게 수납 공간 것 동생 입학 선물 구매 공간 바나나 만큼 후기 ...

# %%
def text_cleaning(text):
    hangul = re.compile('[^ ㄱ-ㅣ 가-힣]')  # 정규 표현식 처리
    result = hangul.sub('', text)
    mecab = Mecab()  # 형태소 추출
    nouns = mecab.nouns(result)
    nouns = [x for x in nouns if len(x) > 1]  # 한글자 키워드 제거
    nouns = [x for x in nouns if x not in stopwords]  # 불용어 제거
    return nouns


vect = CountVectorizer(tokenizer = lambda x: text_cleaning(text5))
print(vect)
#word_list = vect.get_feature_names()
#count_list = bow_vect.toarray().sum(axis=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-182-604804c5de80> in <module>
#      10
#      11 vect = CountVectorizer(tokenizer = lambda x: text_cleaning(text5))
# ---> 12 tdm = vect.fit_transform(text5)
#      13 tdm
#      14 #word_list = vect.get_feature_names()
#
# D:\anaconda\lib\site-packages\sklearn\feature_extraction\text.py in fit_transform(self, raw_documents, y)
#    1186         # TfidfVectorizer.
#    1187         if isinstance(raw_documents, str):
# -> 1188             raise ValueError(
#    1189                 "Iterable over raw text documents expected, "
#    1190                 "string object received.")
#
# ValueError: Iterable over raw text documents expected, string object received.

# %%
# negative_data 를 한 배열에 모두 넣고 명사로 분리
text7 = []
text8 = []
bl=[]
for i in range (len(negative_data)):
    text6 = ' '.join(negative_data[i])
    text7.append(text6)
text8 = ' '.join(text7)
print("")
nl = mecab.nouns(text8)

counter1 = Counter(nl)

# 1글자 제거
available_counter1 = Counter({x: counter1[x] for x in counter1 if len(x) > 1})
available_counter1.most_common(15)
# Out:
# [('가방', 159),
#  ('수납', 87),
#  ('공간', 77),
#  ('디자인', 54),
#  ('만족', 45),
#  ('사이즈', 28),
#  ('생각', 27),
#  ('인형', 27),
#  ('선물', 25),
#  ('마음', 23),
#  ('바나나', 22),
#  ('크기', 20),
#  ('구매', 19),
#  ('고민', 17),
#  ('노트북', 17)]

# %%
print(positive_data)
# Out:
# 1

# %%
print(negative_data)
# Out:
# [['디자인', '자체', '가방', '자체', '크기'], ['디자인', '수납', '공간', '데', '물건', '주머니', '하나', '후기', '가방끈', '말'], ['산지', '얼마', '가방끈', '그게', '건'], ['달기', '환불'], ['수납', '공간', '낭', '낭', '모양'], ['생각', '가법', '막'], ['상품', '때', '상품', '냄새', '나', '머리', '수납', '공간', '생각', '디자인'], ['건', '내구', '책', '데', '이틀', '만', '가방끈', '가방', '부분', '일부', '가방', '사이즈', '가방', '물건', '것', '감안'], ['등', '감출', '디자인', '지퍼', '안쪽', '부직포', '마감', '처리', '별'], ['텍', '정도'], ['수납', '공간', '부족', '후기', '저', '부족', '느'], ['후기', '엉덩이', '글', '엉덩이', '불편', '것', '고민', '저', '제', '원', '크기', '엉덩이', '치지', '일반', '백', '팩', '크기', '것', '키', '엉덩이', '위', '가방', '개', '아무', '거'], ['내구', '것', '로고'], ['디자인', '수납', '공간', '데', '물건', '주머니', '하나', '후기', '가방끈', '말'], ['엔젤', '워', '정신'], ['생각', '넓이', '높이', '단', '단', '듯', '법', '과목', '권', '높이', '책', '곳', '두께', '듯', '가방', '사람', '수납', '공간', '책', '곳', '가방', '목적', '본질', '것', '번', '매쉬', '칸', '번', '칸', '수납', '번', '노트북', '수'], ['인치', '노트북', '수납', '가능', '인치', '무리', '것'], ['상품', '때', '상품', '냄새', '나', '머리', '수납', '공간', '생각', '디자인'], ['생각', '수납', '공간', '가방', '앞'], ['제', '상체', '걸', '수', '가방', 'ㅅ'], ['가방', '디자인', '수납', '공간', '사이즈', '만족', '데', '내구'], ['등딱지', '가방'], ['수납', '공간', '불편'], ['가방', '자체', '사은품', '배송', '생각'], ['학교', '주변', '가방', '정도'], ['빅샷', '이거', '선배', '가방', '바꾸', '정도', '듯'], ['어주', '누주', '주주', '주주', '주주', '주주', '주주', '주주', '주주'], ['가방', '수납', '공간', '여성', '감', '평소', '어깨', '분', '어깨'], ['생각', '가방', '디자인', '안', '주황색', '가방', '안', '느낌'], ['이거', '것'], ['때', '냄새', '삼', '일', '밖', '수납', '공간', '안쪽', '주황색', '게', '띠', '포인트', '생각', '수준', '마크곤잘레스', '글씨', '부분', '부담', '하얀색', '줄', '은색', '가방', '여기저기', '박정', '여행', '때'], ['복학', '가방', '인', '확정', '가방', '요거', '짐'], ['여자', '친구', '정도', '데', '허리', '끝', '선', '길이', '거', '가방']]

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(positive_data)

threshold = 2
total_cnt = len(tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 

for key, value in tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :',total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)

vocab_size = total_cnt - rare_cnt + 2
print('단어 집합의 크기 :',vocab_size)
# Out:
# 단어 집합(vocabulary)의 크기 : 721
# 등장 빈도가 1번 이하인 희귀 단어의 수: 353
# 단어 집합에서 희귀 단어의 비율: 48.95977808599168
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 7.367981632227092
# 단어 집합의 크기 : 370

# %%
sentiment_predict('이 상품 진짜 좋아요... 저는 강추합니다. 대박')
# Out:
# 이 상품 진짜 좋아요... 저는 강추합니다. 대박
# 83.90% 확률로 긍정 리뷰입니다.

# %%
sentiment_predict('학생가방으로 딱이에요 다른가방에 비해 긴편이긴한데 길어서 오히려 이쁜 것같다고 하네요메고 다닐때도 불편한 건 없어서 괜찮아요천사(일명 바나나)인형도 포인트로 생각보다 너무 튀어보이진 않고 귀여워요')

# %%
sentiment_predict('디자인은 마음에 들어요. 지퍼는 조금 불편할것 같아요!')
# Out:
# 92.48% 확률로 긍정 리뷰입니다.

# %%
sentiment_predict('오버핏이라고 생각했지만 생각한것보다 더  크네요!')
# Out:
# 55.55% 확률로 부정 리뷰입니다.

# %%
sentiment_predict('발볼이 너무 조여서 조금 불편하지만 예뻐서 만족합니다 ㅎㅎ')
# Out:
# 94.46% 확률로 긍정 리뷰입니다.

# %%
sentiment_predict('괜찮아요 근데 발볼이 좀 좁고 길이는̆̈ 좀 커요')
# Out:
# 81.09% 확률로 긍정 리뷰입니다.

# %%
sentiment_predict('색깔이 너무 밝고 사진이랑 너무 달라요. 환불하고싶은데 택을 떼버려서 못하는겁니다 다른색깔사세요')
# Out:
# 99.90% 확률로 부정 리뷰입니다.

# %%
sentiment_predict('이쁘긴 한데 얇고 밑에가 늘어나서 핏이 안 이뻐져요 원단도 가격에 비해 좋지 않아서 아쉽네요')
# Out:
# 96.10% 확률로 부정 리뷰입니다.

# %%
sentiment_predict('사이즈 xs s 고민하다가 s 샀는데 그렇게 크다고는 못느끼겠어요 저보다 크신분들이 저랑 같은 사이즈 사시는거 보고 조금 걱정했는데 너무 크지도 않고 그냥 적당히 낙낙해서 입기 좋아요 제 기준 엉덩이 다 덮어요 그리고 뻣뻣한 재질이라 좋았어요 근데 이 가격치곤...실밥도 많이 나오고..')
# Out:
# 95.70% 확률로 긍정 리뷰입니다.

# %%
sentiment_predict('디네뎃답지않게거의정사이즈에가깝네요')
# Out:
# 61.83% 확률로 부정 리뷰입니다.

# %%
sentiment_predict('기본티임 특별할것도 없지만 그렇다고 안좋지도 않음')
# Out:
# 91.95% 확률로 부정 리뷰입니다.
